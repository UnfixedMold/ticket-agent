# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    os.chdir(project_root)

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import torch

print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device count: {torch.cuda.device_count()}")
    print(f"Current CUDA device: {torch.cuda.current_device()}")
    print(f"CUDA device name: {torch.cuda.get_device_name()}")
# Out:
# CUDA available: True
# CUDA device count: 1
# Current CUDA device: 0
# CUDA device name: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
import random
from datetime import datetime, timedelta

PRODUCTS = [
    "Bose QuietComfort Ultra",
    "JBL Charge 5",
    "Sonos Move 2",
    "Apple AirPods Pro (2nd Gen)",
    "Samsung Galaxy Buds2 Pro",
    "Sennheiser Momentum 4",
    "Anker Soundcore Motion X600",
    "Marshall Emberton II",
    "Sony SRS-XG300",
]

PAID_SERVICES = [
    "extended warranty",
    "device protection plan",
    "music streaming bundle",
    "setup assistance service",
    "premium support plan",
]

COUNTRIES = ["Germany", "France", "USA", "UK", "Netherlands", "Sweden"]

COMPANIES = [
    "TechDepot Europe",
    "SmartAudio Direct",
    "GadgetZone Retail",
    "HiFi Distribution Group",
    "Elite Audio Buyers",
]

TONE_STYLES = [
    "Angry and all caps",
    "Overly polite and long-winded",
    "Rushed and fragmented",
    "Confused with multiple questions",
    "Sarcastic",
    "Passive-aggressive",
    "Short and rude",
    "Polite and unsure",
    "Demanding and direct",
    "Overly casual",
    "Helpful and satisfied",
    "Excited and grateful",
    "Neutral and professional",
    "Concerned but polite",
    "Frustrated but calm",
]

VAGUENESS_LEVELS = [
    {
        "name": "clear",
        "description": "Include product name, order number, dates, and detailed context. Both subject and body are present and specific.",
        "weight": 0.3,
    },
    {
        "name": "medium",
        "description": "Include some key info, but leave out details (e.g. no order number). Subject/body may be vague or phrased as a question.",
        "weight": 0.5,
    },
    {
        "name": "vague",
        "description": "Message is emotional or unclear. Subject or body may be missing. Could be as short as 'It’s broken' or 'Need help'.",
        "weight": 0.2,
    },
]

LANGUAGE_QUALITY_LEVELS = [
    {
        "name": "Good",
        "description": "Spelling and grammar mostly correct.",
        "weight": 1,
    },
    {
        "name": "Average",
        "description": "Contains some spelling or grammar mistakes.",
        "weight": 2,
    },
    {
        "name": "Poor",
        "description": "Frequent grammar or spelling issues, slang or typos.",
        "weight": 1,
    },
]

DISTRACTION_TOPICS = [
    "I had a really stressful week and honestly didn't want to deal with this.",
    "My kid accidentally messed with the speaker settings, and I can't even explain what happened.",
    "I tried calling your support line but was on hold for over 40 minutes.",
    "I’ve been a loyal customer for years and never had this kind of issue before.",
    "I was chatting with your bot assistant, but it just looped the same answer.",
    "This may be my fault but I just need someone to walk me through it slowly.",
    "The issue started during a party and it really ruined the mood.",
    "I’m not super tech-savvy, so forgive me if this sounds dumb.",
]


def wrap_seed_with_distraction(seed_info):
    seed_info = dict(seed_info)
    seed_info["distraction_intro"] = random.choice(DISTRACTION_TOPICS)
    return seed_info


def random_order_date(max_days=365, bias_power=2):
    r = random.random()
    days_ago = int((1 - r**bias_power) * max_days)
    return (datetime.today() - timedelta(days=days_ago)).strftime("%B %d")


def tech_support_seed():
    question_only_issues = [
        "where’s the manual?",
        "how long does the battery last?",
        "is it waterproof?",
        "what does the app need?",
        "does it support multipoint?",
        "can it connect to older devices?",
        "what model should I buy?",
        "what features does it have?",
        "will this work with my setup?",
        "need product advice for a specific case",
        "is it compatible with my system?",
    ]
    product_issues = [
        "won't connect",
        "keeps restarting",
        "firmware failed",
        "no sound",
        "blinking lights",
        "overheating",
        "charging issue",
        "won't turn on",
        "Bluetooth not pairing",
        "disconnects randomly",
        "voice assistant doesn’t respond",
        "buttons don’t work",
        "mic not working",
        "buzzing or static noise",
        "volume too low",
        "app can’t find device",
        "touch panel doesn’t respond",
        "firmware update broke it",
    ]
    r = random.random()
    if r < 0.3:
        return {"issue_type": random.choice(question_only_issues)}
    elif r < 0.7:
        return {
            "product": random.choice(PRODUCTS),
            "issue_type": random.choice(product_issues),
        }
    else:
        return {
            "product": random.choice(PRODUCTS),
            "issue_type": random.choice(product_issues),
            "firmware_version": f"{random.randint(2, 5)}.{random.randint(0, 9)}.{random.randint(0, 9)}",
        }


def billing_seed():
    return {
        "service": random.choice(PAID_SERVICES),
        "charge_amount": random.choice(["$9.99", "$19.99", "$49.99"]),
        "charge_date": (
            datetime.today() - timedelta(days=random.randint(1, 25))
        ).strftime("%B %d"),
        "problem": random.choice(
            [
                "unauthorized charge",
                "charged after canceling",
                "duplicate payment",
                "wrong amount billed",
            ]
        ),
        "payment_method": random.choice(["credit card", "PayPal", "Apple Pay"]),
    }


def shipping_seed():
    return {
        "product": random.choice(PRODUCTS),
        "order_number": random.randint(10000, 99999),
        "order_date": random_order_date(),
        "destination_country": random.choice(COUNTRIES),
        "issue": random.choice(
            [
                "not delivered",
                "wrong address",
                "no tracking info",
                "stuck in transit",
                "return label missing",
                "return instructions unclear",
            ]
        ),
        "extra_note": random.choice(
            [
                "needs fast resolution",
                "already emailed once",
                "item needed for event",
                "wants refund after return",
            ]
        ),
    }


def legal_seed():
    return {
        "country": random.choice(COUNTRIES),
        "request_type": random.choice(
            [
                "GDPR data deletion",
                "account removal",
                "privacy concern",
                "policy dispute",
            ]
        ),
        "urgency": random.choice(
            [
                "casual inquiry",
                "demand immediate action",
                "considering legal steps",
            ]
        ),
    }


def sales_seed():
    return {
        "company": random.choice(COMPANIES),
        "product": random.choice(PRODUCTS),
        "quantity": random.choice([10, 25, 50, 100, 250]),
        "interest_type": random.choice(
            [
                "reseller deal",
                "bulk internal use",
                "corporate gifting",
                "influencer campaign",
            ]
        ),
        "deadline": random.choice(["2 weeks", "1 month", "urgent, this week", None]),
        "pre_sale_question": random.choice(
            [
                "asking about pricing",
                "asking about stock availability",
                "asking about shipping time",
                "asking about custom branding",
                "asking about lead time",
                "asking what product is best for their use case",
                "asking what’s available for their budget",
                "asking for general recommendations",
                "asking if they can test a sample unit",
            ]
        ),
    }


def care_seed():
    general_issues = [
        "can't log in",
        "need to change email",
        "can’t access my past orders",
        "trouble reaching support",
        "want to leave feedback",
        "don’t understand how the return policy works",
        "I need to talk to a human",
        "website is broken",
        "I have multiple accounts and want to merge them",
        "need help but don’t know who to contact",
    ]
    return {
        "user_id": f"user_{random.randint(1000, 9999)}",
        "issue": random.choice(general_issues),
        "distraction_intro": random.choice(DISTRACTION_TOPICS),
    }


departments = [
    {
        "name": "Tech Support",
        "description": "Handles questions and problems related to audio products.",
        "seed_info_generator": tech_support_seed,
    },
    {
        "name": "Billing",
        "description": "Handles charges, refunds, and service payment issues.",
        "seed_info_generator": billing_seed,
    },
    {
        "name": "Shipping",
        "description": "Handles delivery, tracking, and return issues for purchases.",
        "seed_info_generator": shipping_seed,
    },
    {
        "name": "Legal",
        "description": "Handles privacy, data, and account-related legal requests.",
        "seed_info_generator": legal_seed,
    },
    {
        "name": "Sales",
        "description": "Handles bulk orders, reseller inquiries, and business purchases.",
        "seed_info_generator": sales_seed,
    },
    {
        "name": "Customer Care",
        "description": "Handles general or unclear issues, feedback, and misrouted messages.",
        "seed_info_generator": care_seed,
    },
]

# %%
import asyncio
import json

from langchain.prompts import ChatPromptTemplate, PromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from langchain_deepseek import ChatDeepSeek
from tqdm.notebook import tqdm

SEMAPHORE_LIMIT = 100

llm = ChatDeepSeek(model="deepseek-chat", temperature=1)

system_prompt = PromptTemplate.from_template("""
You are simulating a real customer writing a support email to a consumer audio tech company.

Instructions:
- ONLY return valid JSON: {{"subject": "...", "body": "...", "department": "..."}}
- Do NOT explain anything or write outside the JSON block.
- Be realistic: include messy grammar, emotional tone, vague questions, or random formatting.
""")

human_prompt = PromptTemplate.from_template("""
Customer tone: {tone_style}
Vagueness level: {vagueness_level}
Vagueness instruction: {vagueness_instruction}
Language level: {language_level}
Language instruction: {language_instruction}

Customer situation/context:
{seed_info_json}

Department: {department}
""")

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt.template),
        ("human", human_prompt.template),
    ]
)

parser = JsonOutputParser()
chain = prompt | llm | parser


semaphore = asyncio.Semaphore(SEMAPHORE_LIMIT)


async def generate_email_async(dept_config):
    seed_info = wrap_seed_with_distraction(dept_config["seed_info_generator"]())

    tone = random.choice(TONE_STYLES)
    vagueness_entry = random.choices(
        VAGUENESS_LEVELS, weights=[e["weight"] for e in VAGUENESS_LEVELS]
    )[0]
    language_entry = random.choices(
        LANGUAGE_QUALITY_LEVELS, weights=[e["weight"] for e in LANGUAGE_QUALITY_LEVELS]
    )[0]

    async with semaphore:
        return await chain.ainvoke(
            {
                "department": dept_config["name"],
                "department_description": dept_config["description"],
                "tone_style": tone,
                "vagueness_level": vagueness_entry["name"],
                "vagueness_instruction": vagueness_entry["description"],
                "seed_info_json": json.dumps(seed_info, indent=2),
                "language_level": language_entry["name"],
                "language_instruction": language_entry["description"],
            }
        )


async def generate_all_emails_async(departments, distribution, emails_total):
    tasks = []
    for dept in departments:
        for _ in range(distribution.get(dept["name"], 0)):
            tasks.append((len(tasks), generate_email_async(dept)))

    results = [None] * len(tasks)
    pbar = tqdm(total=len(tasks), desc="Generating emails", unit="email")

    async def wrapped(idx, coro):
        results[idx] = await coro
        pbar.update(1)

    await asyncio.gather(*[wrapped(i, coro) for i, coro in tasks])
    return results

# %%
await generate_email_async(departments[0])
# Out:
# {'subject': 'Beats Studio Pro not working after update?',
#  'body': "Hey there,\n\nSo I updated my Beats Studio Pro to firmware 5.5.8 and now they're acting all weird. Like, the sound cuts out sometimes and the buttons don't respond right. I had a really stressful week and honestly didn't want to deal with this. Can you help me fix it or do I need to roll back the update?\n\nThanks,",
#  'department': 'Tech Support'}

# %%
TOTAL_EMAILS = 1000

DISTRIBUTION_WEIGHTS = {
    "Tech Support": 0.3,
    "Billing": 0.2,
    "Shipping": 0.2,
    "Legal": 0.1,
    "Sales": 0.15,
    "Customer Care": 0.05,
}

# DISTRIBUTION_WEIGHTS = {
#     "Tech Support": 1 / 6,
#     "Billing": 1 / 6,
#     "Shipping": 1 / 6,
#     "Legal": 1 / 6,
#     "Sales": 1 / 6,
#     "Customer Care": 1 / 6,
# }

department_distribution = {
    dept: round(DISTRIBUTION_WEIGHTS[dept] * TOTAL_EMAILS)
    for dept in DISTRIBUTION_WEIGHTS
}

# %%
all_emails = await generate_all_emails_async(
    departments, department_distribution, TOTAL_EMAILS
)
# Out:
# Generating emails:   0%|          | 0/1000 [00:00<?, ?email/s]

# %%
from helpers.print import print_emails

print_emails(all_emails)
# Out:
# Email 1:
# Subject: Blinking lights on Emberton II
# Body: Hey, so my Marshall Emberton II is doing this weird blinking light thing. I might have messed something up, but I don't know. Just tell me how to fix it, step by step, because I'm not techy. Thanks, I guess.
# Department: Tech Support
# --------------------------------------------------
# Email 2:
# Subject: My Sony speaker isn't working properly?
# Body: Dear Support Team,
#
# I hope this email finds you well! I'm writing because I'm having a bit of trouble with my Sony SRS-XG300 speaker. It just won't turn on, no matter what I try. I was chatting with your bot assistant earlier, but it kept giving me the same answer over and over, which wasn't very helpful, so I thought I'd reach out to a real person.
#
# I'm currently on firmware version 5.0.9, if that helps. I've tried charging it overnight and pressing the power button in different ways, but nothing seems to work. It's quite frustrating because I really love this speaker and use it all the time!
#
# Could you please advise me on what might be wrong and how to fix it? I'd be ever so grateful for your assistance. Thank you so much in advance for your time and help!
#
# Warm regards,
# A Loyal Customer
# Department: Tech Support
# --------------------------------------------------
# Email 3:
# Subject: Speaker keeps disconnecting
# Body: Hi, I have a Sony SRS-XG300 and it keeps disconnecting randomly. I'm on firmware 2.7.1. Also, I tried chatting with your bot but it just kept repeating the same thing. Can you help me fix this? It's really frustrating when it cuts out during music.
# Department: Tech Support
# --------------------------------------------------
# Email 4:
# Subject: Hello there! Quick question about waterproofing...
# Body: Dear wonderful support team,
#
# I hope this email finds you well! First off, I just want to say how much I adore your products - they've been such a game changer for my morning runs. Though, I did have a little chat with your bot earlier about whether the headphones are waterproof, but bless its digital heart, it just kept repeating the same answer over and over like a broken record (no offense to the bot, of course!).
#
# So I thought I'd reach out to you lovely humans instead - could you possibly clarify if the headphones can handle a bit of rain or sweat? I'm not planning to take them swimming or anything crazy like that, but you know how unpredictable weather can be these days!
#
# Thanks a million in advance for your help, and sorry to bother you with what's probably a silly question!
#
# Warmest regards,
# A very loyal (if slightly confused) customer
# Department: Tech Support
# --------------------------------------------------
# Email 5:
# Subject: AirPods Pro not working after update?
# Body: Hi there, I have the AirPods Pro 2nd gen and after the last update (5.2.2 i think) they stopped working right. The sound cuts out and sometimes they dont connect at all. I tried calling but was on hold forever so emailing instead. Can you help fix this? Thanks
# Department: Tech Support
# --------------------------------------------------
# Email 6:
# Subject: Help! My speaker wont update??
# Body: Hey so i got this marshall emberton 2 and its been great but now the firmware thing is not working. I tried like 5 times and it just stops halfway. Been buying your stuff for ages never had this happen before. What do i do??? pls help its really annoying
# Department: Tech Support
# --------------------------------------------------
# Email 7:
# Subject: Help with Momentum 4 firmware issue?
# Body: Hi there,
#
# I've had a really stressful week and honestly didn't want to deal with this, but my Sennheiser Momentum 4 headphones seem to have a firmware problem. They were working fine, then suddenly stopped after what I think was an update? Now they won't connect properly and the app says there's an error.
#
# Can you help me figure out what's wrong? I'm not super techy so not sure what to do next. Thanks for your help!
#
# Best,
# Department: Tech Support
# --------------------------------------------------
# Email 8:
# Subject: Charging problem with my headphones
# Body: Hi there, I hope you are doing well. I just wanted to say first that I’ve been buying Sennheiser for like forever and I never had no problems before but now my Momentum 4 wont charge right? I plug them in and the light comes on but then it goes off and they dont hold no charge. I updated to firmware 5.5.8 like it said but still same thing. I’m really upset because I use these every day for work and now I cant. Please help me fix this asap. Thank you so much for your time and sorry to bother you with this.
# Department: Tech Support
# --------------------------------------------------
# Email 9:
# Subject: JBL Charge 5 Bluetooth Pairing Issue - Order #12345
# Body: Hi there,
#
# I bought the JBL Charge 5 on October 15th (order #12345) and it worked fine for a week. Now it just REFUSES to pair with my phone. I tried resetting it, updating the firmware, even using a different phone—nothing. And your bot assistant? Useless. Kept telling me to 'turn it off and on again' like I hadn't already done that 10 times.
#
# So, what’s the *actual* fix here? Or do I need to return this thing?
#
# Thanks, I guess.
# Department: Tech Support
# --------------------------------------------------
# Email 10:
# Subject: Samsung Galaxy Buds2 Pro not connecting - Order #12345 from 10/15/2023
# Body: Hey guys, i just got my Samsung Galaxy Buds2 Pro last week (order #12345) and i was SO EXCITED!!! But now they wont connect to my phone no matter what i try :( i had a really stressful week and honestly didnt want to deal with this but i love these buds so much pls help!!! I tried resetting them and turning bluetooth on/off but nothing works. Thx u guys are the best!!!
# Department: Tech Support
# --------------------------------------------------
# Email 11:
# Subject: does ur headphones do multipoint??
# Body: hey so i got these headphones from u guys and i was at a party tryna switch between my phone and laptop but it wasnt working?? like it just wouldnt connect to both at same time and it totally killed the vibe u know? can u tell me if these even support multipoint or am i doing something wrong? thx
# Department: Tech Support
# --------------------------------------------------
# Email 12:
# Subject: AirPods Pro acting possessed?
# Body: Hey so my AirPods Pro (2nd gen) keep restarting randomly... like they're trying to meditate or something? Super annoying when I'm trying to listen to music. Also your chat bot was no help - just kept repeating itself like a broken record. What gives?
# Department: Tech Support
# --------------------------------------------------
# Email 13:
# Subject: Help! My Bose headphones keep blinking weird lights??
# Body: Hey so i was trying to use my QuietComfort Ultras and the lights wont stop blinking?? Its like green and red and idk what that means. I think im on firmware 4.5.5 or something like that. Also your chat bot was NO HELP it just kept saying the same thing over and over. Pls tell me how to fix this its really annoying when im trying to listen to music! Thx
# Department: Tech Support
# --------------------------------------------------
# Email 14:
# Subject: Why is my new headphones so quiet??
# Body: Hey so I just got these Sennheiser Momentum 4 headphones and the volume is like... barely there? I had a really stressful week and honestly didn't want to deal with this. I paid good money for these and they sound worse than my old earbuds. What's going on? Is this normal or do I need to return them?
# Department: Tech Support
# --------------------------------------------------
# Email 15:
# Subject: Marshall Emberton II Overheating Issue - Order #78945
# Body: Hi there,
#
# I purchased a Marshall Emberton II (order #78945, purchased on March 15, 2024) and have been experiencing overheating issues. The speaker gets extremely hot after about 30 minutes of use at moderate volume, to the point where it shuts down. I tried calling your support line but was on hold for over 40 minutes before giving up.
#
# Is this normal behavior? It's concerning because I've used other portable speakers without this issue. Could you advise if this is a known problem or if I should request a replacement?
#
# Thanks for your help,
# Alex
# Department: Tech Support
# --------------------------------------------------
# Email 16:
# Subject: Sennheiser Momentum 4 buzzing noise issue - Order #12345
# Body: Hi there,
#
# I recently purchased the Sennheiser Momentum 4 (Order #12345, purchased on 15th October 2023) and I've been experiencing a really annoying buzzing or static noise in the left earcup. I’ve been a loyal customer for years and never had this kind of issue before. It happens mostly when I'm listening to music or podcasts, even at lower volumes. I've tried resetting them and updating the firmware, but the problem persists.
#
# Could you please help me figure out what's going on? I really love these headphones otherwise, but this is making them unusable. Thanks in advance for your assistance!
#
# Best regards,
# John Doe
# Department: Tech Support
# --------------------------------------------------
# Email 17:
# Subject: Beats Studio Pro keeps disconnecting?
# Body: Hey there,
#
# I've been using my Beats Studio Pro for a few months now and love them, but this week they started disconnecting randomly. It's super frustrating because I had a really stressful week and honestly didn't want to deal with this. Sometimes they work fine, other times they cut out every few minutes. I tried resetting them but no luck. Any ideas what's going on?
#
# Thanks,
# A tired customer
# Department: Tech Support
# --------------------------------------------------
# Email 18:
# Subject: Why is my Move 2 so quiet?
# Body: I just got this speaker and the volume is way too low. I tried everything, even maxing it out. What's the point if I can barely hear it? Also, your phone support is a joke - 40 minutes on hold and nothing. Fix this.
# Department: Tech Support
# --------------------------------------------------
# Email 19:
# Subject: Help with my JBL Flip 5 speaker settings messed up by kid
# Body: Hey there,
#
# So my kid was playing with my JBL Flip 5 (order #12345, bought on May 10th) and now the sound is all weird. Like, the bass is gone and it sounds tinny. I tried resetting it but no luck. Can u tell me how to fix this? I dunno what buttons he pressed or anything. Thx.
#
# - Mike
# Department: Tech Support
# --------------------------------------------------
# Email 20:
# Subject: YOUR PRODUCT SUCKS!!!!
# Body: HEY I WAS TALKING TO YOUR STUPID BOT AND IT KEPT SAYING THE SAME THING OVER AND OVER!!! DOES THIS DAMN THING EVEN DO MULTIPOINT OR NOT???? I NEED ANSWERS NOW THIS IS RIDICULUS!!!! FIX IT!!!!
# Department: Tech Support
# --------------------------------------------------
# Email 21:
# Subject: Sonos Move 2 not making any sound?
# Body: Hi there,
#
# I'm having a big problem with my Sonos Move 2 - it's not playing any sound at all! I updated to firmware 4.3.4 last week and not sure if that's related. Tried calling support but waited forever and had to hang up.
#
# I've tried resetting it and checking the app settings but nothing works. The lights come on but no sound comes out. Is this a known issue? Please help!
#
# Thanks,
# Frustrated but trying to be patient
# Department: Tech Support
# --------------------------------------------------
# Email 22:
# Subject: Having trouble charging my Beats Studio Pro
# Body: Hi there,
#
# I think I might be doing something wrong with my Beats Studio Pro headphones. They're not charging properly and I'm not sure what's going on. This may be my fault but I just need someone to walk me through it slowly. I've tried different cables and outlets but no luck. Can you help me figure out what's wrong?
#
# Thanks!
# Department: Tech Support
# --------------------------------------------------
# Email 23:
# Subject: Samsung Galaxy Buds2 Pro keeps disconnecting - FIX IT NOW
# Body: yo i bought these samsung buds2 pro last week and they keep disconnecting all the time. my kid messed with the settings or something idk but its annoying as hell. order #12345 from jan 15. how do i fix this?? its not working right and i want a refund if u cant help.
# Department: Tech Support
# --------------------------------------------------
# Email 24:
# Subject: Is this thing broken or am I just dumb?
# Body: Hey sooo... my Sony WH-1000XM5s decided to take a permanent nap. Won't turn on at all. Firmware is 5.5.1 or whatever. Maybe I did something wrong? I dunno. Can you like... explain it to me like I'm 5 years old? Thanks. Or just tell me they're dead. Either way.
# Department: Tech Support
# --------------------------------------------------
# Email 25:
# Subject: Static noise in my Galaxy Buds2 Pro?
# Body: Hey there,
#
# I think I messed something up with my Galaxy Buds2 Pro. There's this weird buzzing/static noise in one earbud when I listen to music. It's driving me nuts! Can someone help me figure out if this is a setting I accidentally changed or if they're broken? I'm not super techy so please explain like I'm 5.
#
# Thanks,
# A frustrated customer
# Department: Tech Support
# --------------------------------------------------
# Email 26:
# Subject: Sonos Move 2 mic issue after settings got changed
# Body: Hi there,
#
# I'm having trouble with the microphone on my Sonos Move 2. It stopped working after my kid was playing with the settings (I'm on firmware 4.8.6). I've tried resetting it but no luck. Could you help me figure out what's wrong?
#
# Thanks,
# A frustrated but hopeful customer
# Department: Tech Support
# --------------------------------------------------
# Email 27:
# Subject: My Bose headphones keep disconnecting - could you help?
# Body: Dear Bose Support Team,
#
# I hope this email finds you well. I wanted to reach out regarding an issue I've been experiencing with my Bose QuietComfort Ultra headphones. They've been disconnecting randomly, which has been quite frustrating, especially during important calls and while listening to music. I tried calling your support line earlier today, but unfortunately, I was on hold for over 40 minutes and had to hang up due to other commitments.
#
# I was wondering if you might have any suggestions or solutions for this issue? I've tried resetting them and checking the Bluetooth settings, but the problem persists. Any guidance you could provide would be greatly appreciated.
#
# Thank you so much for your time and assistance. I truly value your expertise and look forward to hearing from you soon.
#
# Warm regards,
# Department: Tech Support
# --------------------------------------------------
# Email 28:
# Subject: Marshall Emberton II not connecting to app - firmware 3.6.6
# Body: Hi there,
#
# I had a really stressful week and honestly didn't want to deal with this, but I'm having trouble with my Marshall Emberton II. The app can't find the device at all, even though it worked fine before. I'm on firmware version 3.6.6. I've tried restarting both the speaker and my phone, but no luck. Could you help me figure out what's wrong?
#
# Thanks,
# [Your Name]
# Department: Tech Support
# --------------------------------------------------
# Email 29:
# Subject: Bose QuietComfort Ultra Mic Not Working - Order #123456
# Body: Dear Support Team,
#
# I hope this email finds you well. I wanted to reach out regarding an issue I'm having with my Bose QuietComfort Ultra headphones, which I ordered on October 15th (Order #123456). The microphone seems to have stopped working properly during calls. I can hear the other person just fine, but they can't hear me at all.
#
# I did try calling your support line earlier today, but unfortunately, I was on hold for over 40 minutes and had to hang up due to other commitments. I thought it might be quicker to email, and I'd really appreciate any help you can provide.
#
# Thank you so much for your time and assistance. I look forward to hearing from you soon.
#
# Best regards,
# John Doe
# Department: Tech Support
# --------------------------------------------------
# Email 30:
# Subject: Question about multipoint support on my SoundBlaster X3
# Body: Hi there,
#
# I’ve been a loyal customer for years and never had this kind of issue before. I recently bought the SoundBlaster X3 (order #SBX34567 on May 15th) and I’m not sure if it supports multipoint connections. I tried connecting it to my phone and laptop at the same time but it doesn’t seem to work. Could you clarify if this feature is supported and if so, how to set it up?
#
# Thanks,
# Alex
# Department: Tech Support
# --------------------------------------------------
# Email 31:
# Subject: Buzzing noise in my Beats Studio Pro
# Body: Hi there,
#
# I've been having this really annoying buzzing or static noise in my Beats Studio Pro headphones. I'm on firmware version 5.6.0. I had a super stressful week and this is just the last thing I needed. Can you help me figure out what's going on? Thanks so much.
#
# Best,
# Department: Tech Support
# --------------------------------------------------
# Email 32:
# Subject: Can't find the manual for my device?
# Body: Hi there,
#
# I had a really stressful week and honestly didn't want to deal with this, but I need some help. I recently bought one of your audio devices (I think it's the X200 model?) and I can't find the manual anywhere. The box didn't have one inside, and I checked your website but got lost in all the downloads section.
#
# Could you point me to where I can get a proper manual? I just want to set it up correctly without guessing.
#
# Thanks,
# A tired customer
# Department: Tech Support
# --------------------------------------------------
# Email 33:
# Subject: need help picking new speaker?
# Body: hey so like my kid was messing with the speaker and now it sounds all weird and idk what to do. maybe i need a new one? can u tell me which model is good for like normal music and stuff? not too expensive pls. thx!
# Department: Tech Support
# --------------------------------------------------
# Email 34:
# Subject: Help with my Anker Soundcore Motion X600
# Body: Dear Support Team,
#
# I hope this message finds you well. I’m writing because I’ve been having a bit of trouble with my Anker Soundcore Motion X600, and I’m not super tech-savvy, so forgive me if this sounds dumb. The speaker keeps restarting on its own, and I’m not sure why. It’s really frustrating because I love the sound quality, but this issue is making it hard to enjoy.
#
# I’ve tried turning it off and on again, but that doesn’t seem to help. Could you please advise me on what might be causing this and how to fix it? I’d really appreciate any help you can offer.
#
# Thank you so much for your time and assistance.
#
# Best regards,
# A concerned customer
# Department: Tech Support
# --------------------------------------------------
# Email 35:
# Subject: why no sound???
# Body: hey so i got these momentum 4s and like... they just dont work? no sound at all. firmware is 2.6.7 i think. ive been buying your stuff forever and this is like... not cool. what gives? how do i fix or do i need to return them or what. thanks i guess
# Department: Tech Support
# --------------------------------------------------
# Email 36:
# Subject: Speaker not working right
# Body: Hey so I got this Soundcore speaker and now it's not charging properly or something? My kid was playing with it and now it's just... not right. I don't know what they did but it's not working like it should. The light comes on but then goes off and it's not holding charge. This is really frustrating because it wasn't cheap and now it's just... ugh. Can you fix this or do I need to return it?
# Department: Tech Support
# --------------------------------------------------
# Email 37:
# Subject: Can't find manual - speaker settings messed up?
# Body: Hey, so my kid was playing with the speaker and now it sounds all weird. I think I need to reset it or something but I can't find the manual anywhere. Can you send me a link or tell me how to fix this? The bass sounds like it's underwater and the treble is screechy. Help!
# Department: Tech Support
# --------------------------------------------------
# Email 38:
# Subject: Sony SRS-XG300 buzzing noise issue - Order #45782
# Body: Hi there,
#
# I bought the Sony SRS-XG300 last month (Order #45782, purchased on March 15th) and I've been having this really annoying buzzing or static noise issue. I updated the firmware to version 2.1.5, but it didn't help. This may be my fault but I just need someone to walk me through it slowly. It's really frustrating because I love the speaker otherwise.
#
# Could you please help me figure out what's going on? Maybe it's a setting I messed up or something. Thanks in advance!
#
# Best,
# A frustrated but hopeful customer
# Department: Tech Support
# --------------------------------------------------
# Email 39:
# Subject: help my bose broke
# Body: hey so i was tryin to update my quietcomfort ultra and now its all messed up?? like the screen is stuck and it wont turn off or anything. i was talkin to ur bot thing but it just kept sayin the same stuff over and over. pls help im freakin out here
# Department: Tech Support
# --------------------------------------------------
# Email 40:
# Subject: will this speaker work with my stuff??
# Body: hey so i got this speaker and my kid was playing with the buttons and now it sounds all weird. i dont know what he did but like, will this still work with my tv and phone? also the lights are blinking different colors now and idk if thats bad. pls help its driving me nuts
# Department: Tech Support
# --------------------------------------------------
# Email 41:
# Subject: Sony WH-1000XM5 Won't Turn On - Order #12345
# Body: Hi there,
#
# I hope you're doing well. I'm not super tech-savvy, so forgive me if this sounds dumb. I bought the Sony WH-1000XM5 headphones (order #12345 on June 10th) and they were working fine until yesterday. Now they won't turn on at all. I tried charging them overnight, but no luck. The light doesn't come on or anything.
#
# Is there something I might be doing wrong? Or could this be a defect? Any help would be really appreciated. Thanks so much!
#
# Best,
# John Doe
# Department: Tech Support
# --------------------------------------------------
# Email 42:
# Subject: Help please? My headphones making weird noise
# Body: Dear sirs/madams,
#
# I hope this email finds you well. I am writing because I am having a bit of a problem with my Sennheiser Momentum 4 headphones that I bought not too long ago. I've been a loyal customer for years and never had this kind of issue before, so I'm really confused and a bit upset.
#
# There's this like, buzzing or static noise coming from them when I listen to music or podcasts. It's not all the time but happens a lot and is super annoying. I tried charging them full and resetting but no luck?? Maybe its a wire loose inside or something idk.
#
# Could you please advise what to do? I really love these headphones otherwise and dont want to return if possible. Thank you so much for your time and help in advance.
#
# Best regards,
# A very frustrated but still loyal customer
# Department: Tech Support
# --------------------------------------------------
# Email 43:
# Subject: help with speaker settings???
# Body: hey so my kid was messing with the speakers and now it sounds all weird and i dont know how to fix it. like the bass is too loud or something? idk. can u just tell me how to reset it or whatever. thanks
# Department: Tech Support
# --------------------------------------------------
# Email 44:
# Subject: this speaker is trash
# Body: yo so i got this sony xg300 thing and its making weird noises like buzzing and static??? i paid good money for this and its already broken. tried calling u guys but waited forever and no one picked up. whats the deal?? fix it or give me my money back smh
# Department: Tech Support
# --------------------------------------------------
# Email 45:
# Subject: Missing Manual Inquiry
# Body: Dear Support Team,
#
# I hope this message finds you well. First of all, I want to say how much I appreciate your products—they’ve truly enhanced my listening experience. However, I’m in a bit of a predicament. I recently purchased one of your audio devices, but I can’t seem to locate the manual anywhere. I’ve searched high and low, through every drawer and box, but it’s simply vanished into thin air!
#
# I did attempt to call your support line earlier, but after waiting patiently for over 40 minutes, I thought it might be better to reach out via email. Could you possibly direct me to where I might find a digital copy of the manual? Or perhaps guide me on how to operate the device without it?
#
# Thank you so very much for your time and assistance. I truly appreciate any help you can provide.
#
# Warm regards,
# A Loyal Customer
# Department: Tech Support
# --------------------------------------------------
# Email 46:
# Subject: Samsung Galaxy Buds2 Pro overheating issue - Order #12345
# Body: Dear Support Team,
#
# I hope this email finds you well! I just wanted to reach out because I'm having a bit of a problem with my Samsung Galaxy Buds2 Pro that I bought on October 15th, order number #12345. I'm not super tech-savvy, so forgive me if this sounds dumb, but my earbuds keep getting really hot when I use them for more than like 30 minutes. It's kinda scary, and I'm worried they might, like, explode or something? I've tried charging them with different cables and stuff, but no luck. Could you please help me figure out what's going on? Thank you so much in advance for your time and patience!
#
# Best regards,
# A Concerned Customer
# Department: Tech Support
# --------------------------------------------------
# Email 47:
# Subject: My Beats mic is acting up??
# Body: Hey so like... my Beats Studio Pro mic just stopped working out of nowhere? I think I'm on firmware 4.6.3 but tbh I might have messed something up when I was trying to update. Can someone just like... talk me through this like I'm five? I'm kinda freaking out because I need these for work calls tomorrow. Thanks!!
# Department: Tech Support
# --------------------------------------------------
# Email 48:
# Subject: What features does your product have?
# Body: Hi there,
#
# I was trying to find out more about the features of your product, but your bot assistant wasn't very helpful—it just kept repeating the same answer. Can you give me a rundown of what it can do? I'm really interested but want to make sure it has what I need before buying.
#
# Thanks!
# Department: Tech Support
# --------------------------------------------------
# Email 49:
# Subject: Help choosing the right model for my needs
# Body: Dear Support Team,
#
# I hope this email finds you well. First of all, I want to apologize for the length of this email in advance—I've had a particularly stressful week and honestly didn't want to deal with this, but I know I need to make a decision soon.
#
# I'm looking to purchase a new pair of headphones, specifically the AudioPro X series, but I'm torn between the X200 and X300 models. I placed an order (Order #AUD456789 on October 5th) for the X200, but after reading some reviews, I'm wondering if the X300 would be a better fit for my needs. I primarily use headphones for music production and need something with excellent noise cancellation and long battery life.
#
# Could you kindly advise me on the key differences between these two models? I'd really appreciate any guidance you can offer to help me make the right choice.
#
# Thank you so much for your time and assistance.
#
# Warm regards,
# Department: Tech Support
# --------------------------------------------------
# Email 50:
# Subject: hey wheres the manual??
# Body: hi i just got my new speaker and its AMAZING!!! but i cant find the manual anywhere?? i tried asking ur bot but it just kept saying the same thing over and over lol. can u help me out? thanks!!!
# Department: Tech Support
# --------------------------------------------------
# Email 51:
# Subject: Help pls my buds pro not working right?
# Body: Hi there, I hope this email finds you well! First off, I just wanna say I really love your company and all the great products you make, you guys are awesome! So um, I been having this problem with my Samsung Galaxy Buds2 Pro... I think it might be the firmware or something? They just stopped working properly after I tried to update them. I had a really stressful week and honestly didn't want to deal with this, but now I gotta figure it out. The buds like, won't connect right and the sound is all messed up sometimes. I tried resetting them but no luck. Could you maybe help me out with this? I'd be so so grateful! Thanks a million in advance, you're the best!
# Department: Tech Support
# --------------------------------------------------
# Email 52:
# Subject: How long does the battery last on my JBL Charge 5? Order #12345 from 10/15/23
# Body: Hey, i bought a JBL Charge 5 last month and the battery sucks. It dies in like 2 hours. WTF? I tried calling u guys but was on hold for 40 mins!!! This is ridiculous. How long is it supposed to last? Fix this or I want my money back.
# Department: Tech Support
# --------------------------------------------------
# Email 53:
# Subject: what does the stupid app need to work???
# Body: yo i bought the soundblast 3000 (order #SB456789 on 10/15) and the app keep saying 'missing requirements'. what it NEED?? my phone is new and i aint got time for this crap. had the worst week ever and now this?? just tell me what to do.
# Department: Tech Support
# --------------------------------------------------
# Email 54:
# Subject: WHY DID MY JBL CHARGE 5 STOP WORKING AFTER UPDATE???
# Body: HEY SO I WAS TRYING TO UPDATE MY SPEAKER TO VERSION 2.8.4 AND NOW IT'S JUST DEAD. MY KID WAS PLAYING WITH THE BUTTONS AND NOW I DON'T EVEN KNOW WHAT'S GOING ON. IT WON'T TURN ON OR DO ANYTHING. THIS IS RIDICULOUS, I PAID GOOD MONEY FOR THIS!!! FIX IT NOW!!!!
# Department: Tech Support
# --------------------------------------------------
# Email 55:
# Subject: JBL Charge 5 voice assistant not working
# Body: Hi there,
#
# I love my JBL Charge 5, but I'm having trouble with the voice assistant. It just won't respond when I try to use it. I might be doing something wrong, but I'm not sure what. Could you please help me figure this out? Maybe walk me through the steps slowly?
#
# Thanks so much!
# Department: Tech Support
# --------------------------------------------------
# Email 56:
# Subject: JBL Charge 5 won't turn on
# Body: Hi there,
#
# I'm really hoping you can help me with this. My JBL Charge 5 just won't turn on anymore. I've had it for a while, and it's been working fine until now. I tried calling your support line earlier, but I was on hold for over 40 minutes and had to give up.
#
# I'm not sure what's wrong—it was working yesterday, and now nothing happens when I press the power button. The firmware version is 4.2.0 if that helps. Could you please let me know what I can do to fix this?
#
# Thanks so much for your help.
# Department: Tech Support
# --------------------------------------------------
# Email 57:
# Subject: Compatibility question about the SoundBlaster X4 with my setup
# Body: Hi there,
#
# I recently purchased the SoundBlaster X4 (order #SBX4-2023-45678 on October 15th) and was trying to figure out if it works with my Denon AVR-X2700H receiver. I chatted with your bot assistant, but it kept looping the same answer about checking the manual (which I did - it didn't help).
#
# My setup:
# - Denon AVR-X2700H
# - Windows 11 PC
# - Sony WH-1000XM4 headphones
#
# Can the SoundBlaster X4 output to both the Denon receiver AND the headphones simultaneously? Or do I need to choose one or the other? Also, will the microphone input on the X4 work while using the optical out to the receiver?
#
# Thanks for clarifying - the product page wasn't super clear about these specific cases.
#
# Best,
# Michael
# Department: Tech Support
# --------------------------------------------------
# Email 58:
# Subject: firmware update fail??
# Body: hey so i got these galaxy buds2 pro and tried to update to 3.9.2 but it just keeps saying failed. i restarted phone and buds like 5 times still no luck. also called ur support but was on hold forever so emailing instead. pls help!
# Department: Tech Support
# --------------------------------------------------
# Email 59:
# Subject: JBL Charge 5 voice assistant not working?
# Body: Hi there,
#
# I was at a party last weekend and tried to use the voice assistant on my JBL Charge 5, but it wouldn't respond at all. It was really frustrating because we couldn't play the songs we wanted. I've tried pressing the button and everything, but no luck. Is there a way to fix this or do I need to do something special to get it working again?
#
# Thanks for your help!
# Department: Tech Support
# --------------------------------------------------
# Email 60:
# Subject: Is there a secret handshake to charge these things?
# Body: Hey there,
#
# So I got these fancy Bose QuietComfort Ultras (because apparently I hate money), and I'm having a *fantastic* time trying to charge them. I mean, who needs a simple plug-and-play experience, right? Maybe I'm doing it wrong (wouldn't be the first time), but I swear I've tried every USB cable in my house. Could someone *please* explain how this works like I'm five? Preferably with pictures or interpretive dance.
#
# Thanks,
# A very patient customer (not really)
# Department: Tech Support
# --------------------------------------------------
# Email 61:
# Subject: help plz!!!
# Body: hey so i got this sony xg300 thingy and it was working great at my party but then it just stopped connecting??? like wtf man it totally killed the vibe!!! i tried turning it off and on but no luck. plz help me fix this asap!!! thx u guys rock!!!
# Department: Tech Support
# --------------------------------------------------
# Email 62:
# Subject: Static noise issue with AirPods Pro?
# Body: Hi there,
#
# I've been having this weird buzzing/static sound in my AirPods Pro (2nd Gen) lately, especially when I'm on calls or listening to music. The firmware is up to date (3.0.4). I tried resetting them, but it didn't help. Also, I chatted with your support bot earlier, but it kept repeating the same answer... not very helpful.
#
# Is this a known issue? Any suggestions?
#
# Thanks,
# A concerned customer
# Department: Tech Support
# --------------------------------------------------
# Email 63:
# Subject: Question about waterproofing on SoundBoom Pro X3 (Order #SBX3-2024-5678, purchased May 15, 2024)
# Body: Hi there! I just wanted to say I LOVE my new SoundBoom Pro X3—the bass is insane! I’m not super tech-savvy, so forgive me if this sounds dumb, but I couldn’t find a clear answer in the manual: is it fully waterproof? Like, can I take it in the pool or just light rain? Ordered it May 15 (order #SBX3-2024-5678) and it’s been perfect otherwise. Thanks for making such a great product!
# Department: Tech Support
# --------------------------------------------------
# Email 64:
# Subject: Hi there! My Sonos Move 2 won't turn on?
# Body: Dear Support Team,
#
# I hope this email finds you well! I'm really sorry to bother you with this, but I'm having a bit of trouble with my Sonos Move 2. I'm not super tech-savvy, so forgive me if this sounds dumb. I tried turning it on like usual, but nothing happens? The light doesn't come on or anything. I think I charged it last night but maybe I did it wrong? I don't know what to do now and I'm kinda stressed because I use it every day for my morning yoga. Could you please help me figure out what's going on? Thank you so so much in advance for your patience and help!
#
# Best regards,
# A very confused customer
# Department: Tech Support
# --------------------------------------------------
# Email 65:
# Subject: WHY DO MY BUDS KEEP RESTARTING???
# Body: HEY, I BOUGHT THE SAMSUNG GALAXY BUDS2 PRO AND THEY KEEP RESTARTING FOR NO REASON!! I'M NOT SUPER TECH-SAVVY, SO FORGIVE ME IF THIS SOUNDS DUMB, BUT THIS IS RIDICULOUS. I PAID GOOD MONEY FOR THESE AND THEY DON'T WORK RIGHT. WHAT'S GOING ON?? FIX THIS NOW!!!
# Department: Tech Support
# --------------------------------------------------
# Email 66:
# Subject: Sonos Move 2 Blinking Lights Issue - Order #12345
# Body: Hi, I purchased a Sonos Move 2 on October 15th, 2023 (Order #12345). The speaker has been working fine until yesterday when it started blinking orange and white lights non-stop. I tried resetting it by holding the power button, but the issue persists. This may be my fault, but I just need someone to walk me through it slowly. Can you provide step-by-step instructions to fix this? I need this resolved ASAP as I use it daily for work. Thanks.
# Department: Tech Support
# --------------------------------------------------
# Email 67:
# Subject: Sonos Move 2 mic not working???
# Body: Hey so i got this Sonos Move 2 and the mic just stopped working during a party... like everyone was trying to use it and it was so embarassing. It was working fine before but now nothing. Tried restarting and stuff but no luck. What do i do?? pls help
# Department: Tech Support
# --------------------------------------------------
# Email 68:
# Subject: Did my product come with a manual or was that optional?
# Body: Hey there,
#
# So I bought one of your fancy audio gadgets a while back (great job on the packaging, by the way), but I seem to have misplaced the manual. Or maybe it never existed? I'm not super tech-savvy, so forgive me if this sounds dumb, but I can't figure out how to make this thing work without some instructions. Is there a secret handshake or something I'm missing?
#
# Thanks, I guess.
# Department: Tech Support
# --------------------------------------------------
# Email 69:
# Subject: Will this work with my setup?
# Body: Hey, so I just got your product but I'm not sure if it's compatible with my system. I had a really stressful week and honestly didn't want to deal with this. I have a Mac but not sure which OS version. Will it work or do I need to return it? Thanks.
# Department: Tech Support
# --------------------------------------------------
# Email 70:
# Subject: Will the Sonos Beam work with my Samsung TV?
# Body: I bought a Sonos Beam (Order #45678 on 10/15/2023) and my kid messed with the settings. Now it won't connect to my Samsung QN90A TV. Does this thing even work with my TV or what? Fix it.
# Department: Tech Support
# --------------------------------------------------
# Email 71:
# Subject: Sonos Move 2 won't connect via Bluetooth?
# Body: Hey there,
#
# I was trying to pair my Move 2 with my phone over bluetooth but it just won't connect. The light blinks but nothing happens. I tried restarting both devices, still no luck. Also, I chatted with your bot earlier but it kept giving me the same unhelpful answer over and over...
#
# Can you help me figure this out? It's really frustrating when I just wanna listen to music.
#
# Thanks,
# A tired customer
# Department: Tech Support
# --------------------------------------------------
# Email 72:
# Subject: WHY WON'T YOUR SPEAKER WORK WITH MY SYSTEM???
# Body: HEY I BOUGHT YOUR SPEAKER A WHILE AGO AND NOW IT'S NOT WORKING RIGHT. MY KID WAS MESSING WITH THE SETTINGS AND NOW IT SOUNDS ALL WRONG OR WONT EVEN PLAY. IS THIS THING EVEN COMPATIBLE WITH MY TV?? I DONT HAVE TIME FOR THIS, FIX IT!!!
# Department: Tech Support
# --------------------------------------------------
# Email 73:
# Subject: Question about features for my SoundBlaster X3 (Order #45678 from 10/15/2023)
# Body: Hi there,
#
# I had a really stressful week and honestly didn't want to deal with this, but I need some help. I bought the SoundBlaster X3 last week and I'm kinda confused about what it can do. The box says '7.1 surround' but my computer only shows stereo options? Also does it work with PS5 or just PC? And can I use the mic input while listening to music at the same time?
#
# Sorry if these are dumb questions, just feeling overwhelmed. Thanks for your help!
#
# - Mike
# Department: Tech Support
# --------------------------------------------------
# Email 74:
# Subject: DOES THIS DAMN THING SUPPORT MULTIPOINT OR NOT???
# Body: I’VE BEEN A LOYAL CUSTOMER FOR YEARS AND NEVER HAD THIS KIND OF ISSUE BEFORE. I BOUGHT YOUR LATEST MODEL AND IT'S DRIVING ME CRAZY TRYING TO FIGURE OUT IF IT CONNECTS TO MULTIPLE DEVICES AT ONCE. YOUR WEBSITE IS USELESS AND THE MANUAL MIGHT AS WELL BE IN CHINESE. JUST TELL ME - YES OR NO???
# Department: Tech Support
# --------------------------------------------------
# Email 75:
# Subject: Why do my headphones get so hot?
# Body: I just got these Bose QuietComfort Ultra headphones and they overheat like crazy after 30 minutes. I’m not super tech-savvy, so forgive me if this sounds dumb. But this can't be normal, right? Fix it or I'm returning them.
# Department: Tech Support
# --------------------------------------------------
# Email 76:
# Subject: Sony SRS-XG300 Won't Turn On - Order #12345, Purchased 10/15/2023
# Body: Hey there,
#
# I’m not super tech-savvy, so forgive me if this sounds dumb. But my Sony SRS-XG300 (order #12345, bought on 10/15/2023) just REFUSES to turn on. I’ve tried charging it overnight, pressing every button combo known to man, and even whispering sweet nothings to it—nothing works.
#
# Is this thing just a fancy paperweight now, or am I missing something? Would love some help before I toss it out the window.
#
# Thanks, I guess.
#
# - Frustrated Customer
# Department: Tech Support
# --------------------------------------------------
# Email 77:
# Subject: help!!! my sony headphones broke after update???
# Body: hey so i was at this party right and my WH-1000XM5s were working fine until i did that firmware thingy u sent me. now they like dont turn on or something?? the music just stopped and everyone laughed at me :( how do i fix this?? also sometimes they make weird noises now?? pls help asap this is so annoying!!!!
# Department: Tech Support
# --------------------------------------------------
# Email 78:
# Subject: Help! My speaker stopped working after update?
# Body: Hey there! First off, love your products - my Marshall Emberton II has been awesome until last night. Was at a party and decided to do the firmware update you guys sent... BIG MISTAKE. Now it won't turn on at all! The music died right in the middle of our dance session :( Can you please tell me how to fix this? I tried holding the buttons and charging it but nothing helps. Thanks!
# Department: Tech Support
# --------------------------------------------------
# Email 79:
# Subject: APPLE AIRPODS PRO 2ND GEN OVERHEATING LIKE CRAZY!!! ORDER #12345
# Body: HEY WHAT THE HECK IS GOING ON WITH MY AIRPODS PRO 2ND GEN??? I BOUGHT THEM ON OCTOBER 15TH 2023 (ORDER #12345) AND THEY STARTED OVERHEATING LIKE MAD LAST WEEK. I'VE BEEN A LOYAL CUSTOMER FOR YEARS AND NEVER HAD THIS KIND OF ISSUE BEFORE. NOW I CAN'T EVEN USE THEM FOR MORE THAN 10 MINUTES WITHOUT THEM GETTING SO HOT ITS BURNING MY EARS!!!! FIX THIS NOW OR I WANT A REFUND!!!!
# Department: Tech Support
# --------------------------------------------------
# Email 80:
# Subject: Samsung Galaxy Buds2 Pro firmware fail after update to 5.6.1
# Body: Hi there, I got a problem with my Samsung Galaxy Buds2 Pro. I try to update the firmware to version 5.6.1 but it failed and now they not working right. My kid was playing with the speaker settings and now sound all messed up. I dont know what he did but the buds keep disconnecting and sound is crackling. Pls help fix this. Thx.
# Department: Tech Support
# --------------------------------------------------
# Email 81:
# Subject: Will the SoundBlaster X4 work with my setup?
# Body: Hey there,
#
# So i was trying to figure out if the SoundBlaster X4 (order #12345, bought on Jan 15) will work with my PC running Windows 11 and my old Sony speakers. Your bot just kept saying 'check the specs' over and over... not helpful lol. Can a human confirm? Also, does it need extra drivers or something?
#
# Thanks,
# Dave
# Department: Tech Support
# --------------------------------------------------
# Email 82:
# Subject: Sony SRS-XG300 keeps restarting - Order #45678
# Body: Hey there, i bought the Sony SRS-XG300 last month (order #45678) and its been great until now. But lately it keeps restarting by itself every few minutes?? I was tryna chat with ur bot assistant but it just kept saying the same thing over and over lol. Anyways, can u help me fix this? Its really annoying when im trying to listen to music. Thx!
# Department: Tech Support
# --------------------------------------------------
# Email 83:
# Subject: WHERE IS THE MANUAL???
# Body: I BOUGHT YOUR PRODUCT LAST WEEK AND I CAN'T FIND THE MANUAL ANYWHERE. I HAD A TERRIBLE WEEK AND NOW THIS?? HOW AM I SUPPOSED TO USE THIS THING WITHOUT INSTRUCTIONS? THERE WAS NOTHING IN THE BOX EXCEPT THE DEVICE AND SOME CABLES. THIS IS RIDICULOUS! FIX THIS NOW!
# Department: Tech Support
# --------------------------------------------------
# Email 84:
# Subject: AirPods Pro overheating issue?
# Body: Hey, I've had a really stressful week and honestly didn't want to deal with this, but my AirPods Pro (2nd gen) keep getting really hot when I use them. They're on firmware 3.1.9. Is this normal or should I be worried? They didn't used to do this...
# Department: Tech Support
# --------------------------------------------------
# Email 85:
# Subject: help!!!
# Body: yo my bose speaker is all messed up. lights blinkin like crazy after my kid touched it. fix it now!!!
# Department: Tech Support
# --------------------------------------------------
# Email 86:
# Subject: Beats Studio Pro won't turn on?
# Body: Hey there,
#
# I've had a really stressful week and honestly didn't want to deal with this, but my Beats Studio Pro headphones just won't turn on anymore. I tried charging them overnight and pressing all the buttons, but nothing works. They were fine last week. Can you help me figure out what's wrong?
#
# Thanks,
# A frustrated customer
# Department: Tech Support
# --------------------------------------------------
# Email 87:
# Subject: Help with Emberton II charging??
# Body: Hey so I just got the Marshall Emberton II and I'm having some trouble with charging. I think it's on firmware 4.4.8? Not sure if that matters. It was working fine but now it won't charge at all and I'm freaking out a little. Maybe I did something wrong? The light turns on but nothing happens. Can you just explain it to me like I'm 5? Thanks so much.
# Department: Tech Support
# --------------------------------------------------
# Email 88:
# Subject: Is this normal or...?
# Body: Hey so I just got this Marshall speaker and I'm not super tech-savvy, so forgive me if this sounds dumb. But like... it's making this weird buzzing noise? Not all the time but kinda randomly. I paid good money for this and expected better. Is this how it's supposed to sound or did I get a lemon or something?
# Department: Tech Support
# --------------------------------------------------
# Email 89:
# Subject: Will this work with older equipment?
# Body: Hi there,
#
# I've had a really stressful week and honestly didn't want to deal with this, but I need to know if your product can connect to older devices. I have some equipment from a few years ago and want to make sure they're compatible before I buy.
#
# Thanks for your help,
# A customer
# Department: Tech Support
# --------------------------------------------------
# Email 90:
# Subject: Having trouble charging my JBL speaker?
# Body: Hey there! I absolutely LOVE my JBL Charge 5, but I'm having some weird charging issues after my kid got hold of it. The firmware is 4.1.8, but now it won't charge properly no matter what cable I use. It was working fine before... did something get messed up in the settings? Any help would be awesome, thanks so much!
# Department: Tech Support
# --------------------------------------------------
# Email 91:
# Subject: AirPods mic issue... again
# Body: So my AirPods Pro mic just decided to stop working. Great. Was trying to talk to someone and nada. Also, your bot assistant? Useless. Kept saying the same thing over and over. Fix this please, or do I need to take my business elsewhere?
# Department: Tech Support
# --------------------------------------------------
# Email 92:
# Subject: Why won't my speaker turn on???
# Body: Hey Sony,
#
# I’ve been a loyal customer for years and never had this kind of issue before. Just bought your SRS-XG300 and it was working fine for like a week, now it just... doesn't turn on? Tried charging it overnight, holding the button, nothing. What gives? I expected better from Sony tbh.
#
# Not sure what else to do here, kinda dissapointed. Let me know how to fix this or if I need to return it or something.
#
# Thanks, I guess...
# Department: Tech Support
# ...
# Body: Hi there,
#
# I recently purchased the SoundWave Pro speaker (order #45678 on March 15th) and I'm not entirely sure how the return policy works. My kid was playing with the settings and now the speaker sounds off, but I'm not sure if that's covered. Could you clarify the return process and if this situation applies?
#
# Thanks,
# User_1157
# Department: Customer Care
# --------------------------------------------------
# Email 968:
# Subject: Having trouble reaching support? Speaker settings issue
# Body: Dear Support Team,
#
# I hope this message finds you well. I wanted to reach out because I've been having a bit of trouble getting in touch with your support team, and I'm not entirely sure if my previous attempts went through.
#
# On top of that, my little one got ahold of my speaker and, well, let's just say the settings are now a complete mystery to me. I can't quite put my finger on what exactly changed, but it's definitely not working like it used to. The sound is all off, and I'm at a loss for how to fix it.
#
# I'd be ever so grateful if you could point me in the right direction or perhaps provide some guidance on resetting the settings to their default state. I apologize for not having more specifics—it's all a bit confusing at the moment.
#
# Thank you so much for your time and assistance. I truly appreciate all the help you can offer.
#
# Warm regards,
# A very confused customer
# Department: Customer Care
# --------------------------------------------------
# Email 969:
# Subject: Can't change my email???
# Body: hey so i need to change my email but i dont know how to do it. i'm not super tech-savvy, so forgive me if this sounds dumb. but like, why is this so hard? i tried looking in settings but nothing works. can u just do it for me? thanks i guess.
# Department: Customer Care
# --------------------------------------------------
# Email 970:
# Subject: Can't get through to support?
# Body: Hey, I was trying to get help through your chat thing but it just kept repeating the same useless response. I need actual human help here! What's going on with your support system? I've been waiting forever and getting nowhere. Fix this please!
# Department: Customer Care
# --------------------------------------------------
# Email 971:
# Subject: Is your support team on vacation or just ignoring me?
# Body: Hey there,
#
# So I was trying to get some help from your oh-so-helpful bot assistant, but guess what? It just kept giving me the same answer on repeat. Groundbreaking stuff, really. Now I'm stuck in this endless loop of frustration. Can an actual human maybe step in and help, or is that too much to ask?
#
# Cheers,
# A very patient customer (not really)
# Department: Customer Care
# --------------------------------------------------
# Email 972:
# Subject: Need help with my Sonos speaker settings messed up by my kid
# Body: Hi there,
#
# I'm user_8691 and I really need some help. My kid was playing around with my Sonos speaker (order #SON45678, purchased on 15th March) and now the settings are all messed up. I don't even know what they did, but nothing sounds right anymore. Can you please guide me on how to reset or fix this? I'm kinda in a rush because we have guests coming over tonight.
#
# Thanks,
# A stressed parent
# Department: Customer Care
# --------------------------------------------------
# Email 973:
# Subject: Feedback on my experience
# Body: Hi there,
#
# I'm not super tech-savvy, so forgive me if this sounds dumb. I just wanted to leave some feedback about my experience with your product. It's been... mixed, I guess? Some things work great, others not so much. I'm not even sure where to start, but I figured I should say something. Can someone help me sort through this?
#
# Thanks,
# user_7359
# Department: Customer Care
# --------------------------------------------------
# Email 974:
# Subject: Multiple Accounts Merge Request - Order #AB12345
# Body: Hey there,
#
# So, I've got this *brilliant* situation where I somehow ended up with two accounts (user_8314 and another one linked to my email). I’d love to merge them because, you know, managing two is just *so* much fun.
#
# Oh, and while we’re at it, your bot assistant was *super* helpful—kept telling me the same thing over and over. Really top-notch stuff. Anyway, here are the details:
#
# - Order #AB12345 (placed on 10/15/2023)
# - Product: Wireless Earbuds Pro
# - Accounts: user_8314 and johndoe@email.com
#
# Let me know how this magical merge happens. Or if the bot can finally give me a new response.
#
# Thanks, I guess.
#
# -John
# Department: Customer Care
# --------------------------------------------------
# Email 975:
# Subject: cant login????
# Body: hey so like i was at this party and tryna show off my sick speakers but then i couldnt login??? like what gives?? the app just kept saying error and now my friends think im a loser. pls fix asap thx
# Department: Customer Care
# --------------------------------------------------
# Email 976:
# Subject: Need help
# Body: Hey, so like i need to talk to a real person? not a bot. i got some issues but im not good with tech stuff so pls help. thx
# Department: Customer Care
# --------------------------------------------------
# Email 977:
# Subject: Confused about return policy?
# Body: Hi there,
#
# I recently bought some headphones from you guys and I'm not super tech-savvy, so forgive me if this sounds dumb. But I don’t really understand how the return policy works? Like, how long do I have to return them if they don't work out? And do I have to pay for shipping or anything?
#
# Thanks for your help,
# A confused customer
# Department: Customer Care
# --------------------------------------------------
# Email 978:
# Subject: cant login!!!!
# Body: hey i cant login to my account and i tried calling but was on hold forever like 40 mins!!! this is so frustrating pls help asap
# Department: Customer Care
# --------------------------------------------------
# Email 979:
# Subject: Love your product! But have a quick question...
# Body: Hi there!
#
# I just wanted to say how much I LOVE your speakers - the sound is amazing!! But I think I might be doing something wrong with the setup? This may be my fault but I just need someone to walk me through it slowly. Also wanted to leave some feedback if possible!
#
# Thanks so much,
# A happy customer
# Department: Customer Care
# --------------------------------------------------
# Email 980:
# Subject: help me
# Body: i dont no who to talk to my thing is broke and i need help now!!!
# Department: Customer Care
# --------------------------------------------------
# Email 981:
# Subject: CAN'T LOG IN TO MY ACCOUNT - ORDER #A12345 - URGENT!!!
# Body: HEY I AM USER_1969 AND I CANT LOG IN TO MY ACCOUNT!!! I WAS TRYING TO CHAT WITH YOUR STUPID BOT BUT IT KEPT SAYING THE SAME THING OVER AND OVER LIKE A BROKEN RECORD!!! I NEED HELP NOW MY ORDER #A12345 FROM 10/15/2023 IS STUCK AND I CANT CHECK IT FIX THIS NOW OR I WANT A REFUND!!!!
# Department: Customer Care
# --------------------------------------------------
# Email 982:
# Subject: Can't reach support for my order #ORD78923 - Sony WH-1000XM4
# Body: I placed my order on 10/15/2023 and have been trying to get help for days. Your support line is useless. I need someone to call me back ASAP. This is ridiculous.
# Department: Customer Care
# --------------------------------------------------
# Email 983:
# Subject: WHY CANT I LOG IN??
# Body: hey i been tryin to log in for HOURS and it just wont work. i been a customer for years and this NEVER happened before. whats goin on?? my username is user_6802 but the password aint workin. FIX IT ASAP!!!
# Department: Customer Care
# --------------------------------------------------
# Email 984:
# Subject: Need to change my email address - Order #A7837B2
# Body: Hey there,
#
# I bought a SoundBlaster X3 from yall on March 15th, order #A7837B2. I need to change the email on my account but cant figure out how??? I tried calling support but was on hold like 40 mins and gave up. Can u just tell me where to do this?? Also will this mess up my warranty or anything?? Pls help im so confused.
#
# Thanks,
# user_7837
# Department: Customer Care
# --------------------------------------------------
# Email 985:
# Subject: WHY IS YOUR WEBSITE BROKEN??? FIX IT NOW!!!
# Body: HEY SO I WAS TRYING TO BUY SOME SPEAKERS BUT YOUR SITE IS ALL MESSED UP!!! MY KID WAS PLAYING WITH THE SETTINGS AND NOW I CANT EVEN LOG IN OR ANYTHING. THIS IS RIDICULOUS!!! WHATS GOING ON??? I NEED HELP ASAP!!!!
# Department: Customer Care
# --------------------------------------------------
# Email 986:
# Subject: Need to change my email address for account user_7036
# Body: Hi there,
#
# I hope you're doing well. I need to change the email address associated with my account (user_7036). I think I set it up a while ago, but I can't remember the exact date. Also, my kid was playing with my speaker settings, and now everything sounds weird—but that's a separate issue, haha.
#
# Could you help me update my email? I'd really appreciate it. Thanks!
#
# Best regards,
# A confused but polite customer
# Department: Customer Care
# --------------------------------------------------
# Email 987:
# Subject: Help needed to update my email address please?
# Body: Dear Support Team,
#
# I hope this message finds you well. I'm writing because I seem to be having a bit of trouble updating my email address associated with my account. This may very well be my fault, as technology isn't always my strongest suit, but I would truly appreciate if someone could kindly walk me through the process step by step.
#
# I've tried looking in the account settings, but I'm not entirely sure if I'm in the right place or if I'm missing something obvious. I don't want to mess anything up, so I thought it best to reach out for assistance.
#
# Thank you so very much for your patience and help with this matter. I really do appreciate your time and support.
#
# Warm regards,
# A slightly confused but very grateful customer
# Department: Customer Care
# --------------------------------------------------
# Email 988:
# Subject: Request to Merge Multiple Accounts - User ID: user_8929
# Body: Hello,
#
# I hope you're doing well. I have multiple accounts with your company and would like to merge them into one. My main account is under User ID: user_8929. Could you please assist me with this process?
#
# Also, unrelated but while I have you, my kid accidentally messed with the speaker settings on my device, and now the sound is all off. I can't even explain what happened, but maybe you can help with that too?
#
# Thanks in advance for your support.
#
# Best regards,
# [Your Name]
# Department: Customer Care
# --------------------------------------------------
# Email 989:
# Subject: Who do I talk to about my problem?
# Body: I bought something from you guys and it's not working right. I don't know who to contact or what to do. Help me fix this ASAP.
# Department: Customer Care
# --------------------------------------------------
# Email 990:
# Subject: How does your return policy work?
# Body: Hey there,
#
# So I was trying to figure out how to return something I bought from you guys, but your bot assistant wasn't much help—just kept repeating the same thing. Can you break it down for me in simple terms? Like, how long do I have to return it, and do I need to pay for shipping? Also, what's the deal with restocking fees?
#
# Thanks!
# Department: Customer Care
# --------------------------------------------------
# Email 991:
# Subject: speaker messed up??
# Body: hey so my kid was playing with the speaker and now it sounds all weird. like the bass is gone or something? idk how to fix it. can u help or do i need a new one? its not that old...
# Department: Customer Care
# --------------------------------------------------
# Email 992:
# Subject: How do returns work??
# Body: Hey so i bought some headphones last month and theyre not working right. Had a crazy week and dont have time for this but need to return them. How does the return policy work? Do i just send them back or what? Also how long does it take to get my money back? Thanks
# Department: Customer Care
# --------------------------------------------------
# Email 993:
# Subject: Need Assistance with Recent Order #A3835-2024
# Body: Hi there,
#
# I've been a loyal customer for years and never had this kind of issue before. I recently placed an order on March 15, 2024 (Order #A3835-2024) for the SoundMax Pro headphones, but I haven't received any shipping confirmation yet. Could you please check the status of my order and let me know when I can expect it to arrive?
#
# Thanks for your help!
#
# Best regards,
# User_3835
# Department: Customer Care
# --------------------------------------------------
# Email 994:
# Subject: Help with updating my email address?
# Body: Dear Support Team,
#
# I hope this message finds you well! I just wanted to start by saying how much I appreciate your products—I’ve been a loyal customer for years and never had this kind of issue before. That said, I’m reaching out because I need to change the email address associated with my account. I’m not sure how to do this myself, and I’d hate to lose access to my purchase history or anything important.
#
# Could you kindly guide me through the process? I think I might have tried updating it once before, but I’m not entirely sure if it worked. Also, if there’s anything else I need to do on my end, please let me know!
#
# Thank you so much for your time and assistance. I truly appreciate it!
#
# Best regards,
# A very grateful customer
# Department: Customer Care
# --------------------------------------------------
# Email 995:
# Subject: your website sux
# Body: yo i was tryna play music at my party and your stupid site wouldnt work. ruined the whole vibe. fix it asap!!!
# Department: Customer Care
# --------------------------------------------------
# Email 996:
# Subject: Feedback on Recent Experience with SoundBlast Pro
# Body: Dear Customer Care,
#
# I’ve been a loyal customer for years and never had this kind of issue before. I purchased the SoundBlast Pro (Order #SB-2023-1166) on October 15, 2023, and while the sound quality is decent, the Bluetooth connectivity is absolutely terrible. It drops constantly, and the pairing process is a nightmare. For a premium product, this is unacceptable. I expected better from your brand.
#
# I’d appreciate it if someone could address this or at least acknowledge the feedback. Thanks.
# Department: Customer Care
# --------------------------------------------------
# Email 997:
# Subject: Feedback about my recent experience
# Body: Hi there,
#
# I wanted to share some feedback about my recent experience with your product. It's been a stressful week, so I'm just getting around to this now. Overall, I like the product, but there were a few things that could be improved. The sound quality is great, but I had some issues with the connectivity. Also, the instructions could be clearer. Can you let me know if there's a better way to set it up?
#
# Thanks,
# User_2404
# Department: Customer Care
# --------------------------------------------------
# Email 998:
# Subject: Having trouble getting help?
# Body: Hey there,
#
# I'm not super tech-savvy, so forgive me if this sounds dumb, but I've been trying to reach support and it's like hitting a brick wall. I sent an email a while ago and nada. Am I missing something? Just need some help with my device, nothing crazy.
#
# Thanks,
# A frustrated customer
# Department: Customer Care
# --------------------------------------------------
# Email 999:
# Subject: Cant see my past orders - order #4626 from 10/15/23
# Body: Hey so like i was tryin to check my old orders for the JBL Flip 5 i bought last month but the site keeps sayin error or somethin?? my user id is user_4626. also my kid was messin with my account n now the speaker sounds weird but thats another thing lol. pls help me find my order thx
# Department: Customer Care
# --------------------------------------------------
# Email 1000:
# Subject: Can't log in and your bot is useless
# Body: Hey, so I was trying to log in and it's not working. And your bot assistant? Just kept repeating the same thing over and over. Super helpful, NOT. Fix this please?
# Department: Customer Care
# --------------------------------------------------

# %%
import pandas as pd

df = pd.DataFrame(all_emails)

df
# Out:
#                                                subject  \
# 0                       Blinking lights on Emberton II
# 1              My Sony speaker isn't working properly?
# 2                          Speaker keeps disconnecting
# 3    Hello there! Quick question about waterproofin...
# 4                AirPods Pro not working after update?
# ..                                                 ...
# 995  Feedback on Recent Experience with SoundBlast Pro
# 996                Feedback about my recent experience
# 997                       Having trouble getting help?
# 998  Cant see my past orders - order #4626 from 10/...
# 999               Can't log in and your bot is useless
#
#                                                   body     department
# 0    Hey, so my Marshall Emberton II is doing this ...   Tech Support
# 1    Dear Support Team,\n\nI hope this email finds ...   Tech Support
# 2    Hi, I have a Sony SRS-XG300 and it keeps disco...   Tech Support
# 3    Dear wonderful support team,\n\nI hope this em...   Tech Support
# 4    Hi there, I have the AirPods Pro 2nd gen and a...   Tech Support
# ..                                                 ...            ...
# 995  Dear Customer Care,\n\nI’ve been a loyal custo...  Customer Care
# 996  Hi there,\n\nI wanted to share some feedback a...  Customer Care
# 997  Hey there,\n\nI'm not super tech-savvy, so for...  Customer Care
# 998  Hey so like i was tryin to check my old orders...  Customer Care
# 999  Hey, so I was trying to log in and it's not wo...  Customer Care
#
# [1000 rows x 3 columns]

# %%
import pandas as pd

from paths import DATA_DIR

df = pd.read_csv(DATA_DIR / "customer_support_emails_dataset.csv", index_col=0)

df.head()
# Out:
#                                              subject  \
# 0                     Blinking lights on Emberton II
# 1            My Sony speaker isn't working properly?
# 2                        Speaker keeps disconnecting
# 3  Hello there! Quick question about waterproofin...
# 4              AirPods Pro not working after update?
#
#                                                 body    department
# 0  Hey, so my Marshall Emberton II is doing this ...  Tech Support
# 1  Dear Support Team,\n\nI hope this email finds ...  Tech Support
# 2  Hi, I have a Sony SRS-XG300 and it keeps disco...  Tech Support
# 3  Dear wonderful support team,\n\nI hope this em...  Tech Support
# 4  Hi there, I have the AirPods Pro 2nd gen and a...  Tech Support

# %%
from datasets import Dataset

from helpers.const import HF_HUB_DATASET_ID

dataset = Dataset.from_pandas(df, preserve_index=False)

dataset.push_to_hub(HF_HUB_DATASET_ID)
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/h3en1x/audio-retailer-customer-support-tickets/commit/e749d058b4edba025f56c93a4f46a298cf3fe647', commit_message='Upload dataset', commit_description='', oid='e749d058b4edba025f56c93a4f46a298cf3fe647', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/h3en1x/audio-retailer-customer-support-tickets', endpoint='https://huggingface.co', repo_type='dataset', repo_id='h3en1x/audio-retailer-customer-support-tickets'), pr_revision=None, pr_num=None)
