# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
    os.chdir(project_root)

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# False

# %%
import torch

print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device count: {torch.cuda.device_count()}")
    print(f"Current CUDA device: {torch.cuda.current_device()}")
    print(f"CUDA device name: {torch.cuda.get_device_name()}")
# Out:
# CUDA available: True
# CUDA device count: 1
# Current CUDA device: 0
# CUDA device name: NVIDIA GeForce RTX 3060 Laptop GPU

# %%
import random
from datetime import datetime, timedelta

PRODUCTS = [
    "EchoWave One",
    "EchoWave Mini",
    "SoundBar Flex",
    "BassHub Pro",
    "AuraPods",
    "StreamLink Hub",
    "PulseDock",
    "WavePanel Touch",
    "EchoWave One Plus",
    "AuraPods Gen 2",
    "BassHub Pro Limited",
]

SUBSCRIPTIONS = [
    "Echo+ Unlimited",
    "SmartSound Premium",
    "HomeAudio Pro",
]

COUNTRIES = ["Germany", "France", "USA", "UK", "Netherlands", "Sweden"]

COMPANIES = [
    "AudioCore Distributors",
    "MegaTech Retail",
    "GlobalElectro",
    "Elite Sound Partners",
    "NextWav Studios",
]

TONE_STYLES = [
    "Angry and all caps",
    "Overly polite and long-winded",
    "Rushed and fragmented",
    "Confused with multiple questions",
    "Sarcastic",
    "Passive-aggressive",
    "Short and rude",
    "Polite and unsure",
    "Demanding and direct",
    "Overly casual",
    "Helpful and satisfied",
    "Excited and grateful",
    "Neutral and professional",
    "Concerned but polite",
    "Frustrated but calm",
]

VAGUENESS_LEVELS = [
    {
        "name": "clear",
        "description": "Include product name, order number, dates, and detailed context. Both subject and body are present and specific.",
        "weight": 0.3,
    },
    {
        "name": "medium",
        "description": "Include some key info, but leave out details (e.g. no order number). Subject/body may be vague or phrased as a question.",
        "weight": 0.5,
    },
    {
        "name": "vague",
        "description": "Message is emotional or unclear. Subject or body may be missing. Could be as short as 'It’s broken' or 'Need help'.",
        "weight": 0.2,
    },
]


def random_order_date(max_days=365, bias_power=2):
    r = random.random()
    days_ago = int((1 - r**bias_power) * max_days)
    return (datetime.today() - timedelta(days=days_ago)).strftime("%B %d")


def tech_support_seed():
    question_only_issues = [
        "where’s the manual?",
        "how long does the battery last?",
        "is it waterproof?",
        "what does the app need?",
        "does it support multipoint?",
        "can it connect to older devices?",
        "what model should I buy?",
        "what features does it have?",
        "will this work with my setup?",
        "need product advice for a specific case",
        "is it compatible with my system?",
    ]
    product_issues = [
        "won't connect",
        "keeps restarting",
        "firmware failed",
        "no sound",
        "blinking lights",
        "overheating",
        "charging issue",
        "won't turn on",
        "Bluetooth not pairing",
        "disconnects randomly",
        "voice assistant doesn’t respond",
        "buttons don’t work",
        "mic not working",
        "buzzing or static noise",
        "volume too low",
        "app can’t find device",
        "touch panel doesn’t respond",
        "firmware update broke it",
    ]
    r = random.random()
    if r < 0.3:
        return {"issue_type": random.choice(question_only_issues)}
    elif r < 0.7:
        return {
            "product": random.choice(PRODUCTS),
            "issue_type": random.choice(product_issues),
        }
    else:
        return {
            "product": random.choice(PRODUCTS),
            "issue_type": random.choice(product_issues),
            "firmware_version": f"{random.randint(2, 5)}.{random.randint(0, 9)}.{random.randint(0, 9)}",
        }


def billing_seed():
    return {
        "subscription": random.choice(SUBSCRIPTIONS),
        "charge_amount": random.choice(["$14.99", "$29.99", "$7.99"]),
        "charge_date": (
            datetime.today() - timedelta(days=random.randint(1, 25))
        ).strftime("%B %d"),
        "problem": random.choice(
            [
                "unexpected charge",
                "charged after cancel",
                "double billing",
                "invoice mismatch",
            ]
        ),
        "billing_method": random.choice(["credit card", "paypal", "bank account"]),
    }


def shipping_seed():
    return {
        "product": random.choice(PRODUCTS),
        "order_number": random.randint(10000, 99999),
        "order_date": random_order_date(),
        "destination_country": random.choice(COUNTRIES),
        "issue": random.choice(
            [
                "not delivered",
                "wrong address",
                "no tracking info",
                "stuck in transit",
                "return label missing",
                "return instructions unclear",
            ]
        ),
        "extra_note": random.choice(
            [
                "needs fast resolution",
                "already emailed once",
                "item needed for event",
                "wants refund after return",
            ]
        ),
    }


def legal_seed():
    return {
        "country": random.choice(COUNTRIES),
        "request_type": random.choice(
            [
                "GDPR data deletion",
                "account removal",
                "privacy concern",
                "policy dispute",
            ]
        ),
        "urgency": random.choice(
            [
                "casual inquiry",
                "demand immediate action",
                "considering legal steps",
            ]
        ),
    }


def sales_seed():
    return {
        "company": random.choice(COMPANIES),
        "product": random.choice(PRODUCTS),
        "quantity": random.choice([10, 25, 50, 100, 250]),
        "interest_type": random.choice(
            [
                "reseller deal",
                "bulk internal use",
                "corporate gifting",
                "influencer campaign",
            ]
        ),
        "deadline": random.choice(["2 weeks", "1 month", "urgent, this week", None]),
        "pre_sale_question": random.choice(
            [
                "asking about pricing",
                "asking about stock availability",
                "asking about shipping time",
                "asking about custom branding",
                "asking about lead time",
                "asking what product is best for their use case",
                "asking what’s available for their budget",
                "asking for general recommendations",
                "asking if they can test a sample unit",
            ]
        ),
    }


departments = [
    {
        "name": "Tech Support",
        "description": "Handles product problems and questions: connectivity, audio issues, firmware bugs, app/device failures, or general usage questions.",
        "seed_info_generator": tech_support_seed,
    },
    {
        "name": "Billing",
        "description": "Handles charges, refunds, subscription problems, billing method issues, and cancellations.",
        "seed_info_generator": billing_seed,
    },
    {
        "name": "Shipping",
        "description": "Handles delivery delays, missing packages, incorrect shipments, returns, and tracking problems.",
        "seed_info_generator": shipping_seed,
    },
    {
        "name": "Legal",
        "description": "Handles GDPR, account deletion, privacy concerns, policy disputes, and legal threats.",
        "seed_info_generator": legal_seed,
    },
    {
        "name": "Sales",
        "description": "Handles bulk orders, reseller and B2B inquiries, influencer campaigns, and corporate gifting.",
        "seed_info_generator": sales_seed,
    },
]

# %%
import asyncio
import json

from langchain.prompts import ChatPromptTemplate, PromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from langchain_deepseek import ChatDeepSeek
from tqdm.notebook import tqdm

llm = ChatDeepSeek(model="deepseek-chat", temperature=1)

system_prompt = PromptTemplate.from_template("""
You are simulating a real customer writing a support email to a consumer audio tech company.

Instructions:
- ONLY return valid JSON: {{"subject": "...", "body": "...", "department": "..."}}
- Do NOT explain anything or write outside the JSON block.

Vagueness rules:
- If vagueness_level = "clear":
    - Include product name, order number, dates, and details.
    - Both subject and body should be present and specific.
- If vagueness_level = "medium":
    - Include some key info, but leave out details (e.g. no order number).
    - Subject/body may be vague, short, or phrased as a question.
- If vagueness_level = "vague":
    - Message should be emotional, minimal, or unclear.
    - Subject OR body may be completely empty.
    - OK to include messages like: "Need help." / "It’s broken." / "WTF is this charge???"
    - Avoid any polished structure.

Be realistic: messy grammar, emotional tone, or random format is fine.
""")

human_prompt = PromptTemplate.from_template("""
Customer tone: {tone_style}
Vagueness level: {vagueness_level}
Vagueness instruction: {vagueness_instruction}

Customer situation/context:
{seed_info_json}

Department: {department}
""")

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt.template),
        ("human", human_prompt.template),
    ]
)


parser = JsonOutputParser()

chain = prompt | llm | parser


async def generate_email_async(dept_config):
    seed_info = dept_config["seed_info_generator"]()
    tone = random.choice(TONE_STYLES)
    vagueness_entry = random.choices(
        VAGUENESS_LEVELS, weights=[e["weight"] for e in VAGUENESS_LEVELS]
    )[0]
    output = await chain.ainvoke(
        {
            "department": dept_config["name"],
            "department_description": dept_config["description"],
            "tone_style": tone,
            "vagueness_level": vagueness_entry["name"],
            "vagueness_instruction": vagueness_entry["description"],
            "seed_info_json": json.dumps(seed_info, indent=2),
        }
    )

    return output


async def generate_all_emails_async(departments, distribution, emails_total):
    tasks = []
    for dept in departments:
        for _ in range(distribution.get(dept["name"], 0)):
            tasks.append(generate_email_async(dept))

    results = [None] * len(tasks)
    pbar = tqdm(total=len(tasks), desc="Generating emails", unit="email")

    async def wrapped(idx, coro):
        result = await coro
        results[idx] = result
        pbar.update(1)

    await asyncio.gather(*[wrapped(i, task) for i, task in enumerate(tasks)])
    return results

# %%
await generate_email_async(departments[0])
# Out:
# {'subject': 'EchoWave keeps dropping',
#  'body': 'Disconnects all the time. Fix it!',
#  'department': 'Tech Support'}

# %%
TOTAL_EMAILS = 2000

DISTRIBUTION_WEIGHTS = {
    "Tech Support": 0.3,
    "Billing": 0.2,
    "Shipping": 0.25,
    "Legal": 0.1,
    "Sales": 0.15,
}

department_distribution = {
    dept: round(DISTRIBUTION_WEIGHTS[dept] * TOTAL_EMAILS)
    for dept in DISTRIBUTION_WEIGHTS
}

# %%
all_emails = await generate_all_emails_async(
    departments, department_distribution, TOTAL_EMAILS
)
# Out:
# Generating emails:   0%|          | 0/100 [00:00<?, ?email/s]

# %%
for i, email in enumerate(all_emails):
    print(f"Email {i + 1}:")
    print(f"Subject: {email['subject']}")
    print(f"Body: {email['body']}")
    print(f"Department: {email['department']}")
    print("-" * 50)
# Out:
# Email 1:
# Subject: Is the SoundBuds Pro truly waterproof? Need clarification ASAP.
# Body: I recently purchased the SoundBuds Pro (Order #SB12345 on 05/15/2024) and the product description claims it's waterproof. However, I can't find any details about the IP rating or how long it can be submerged. I need a clear answer before I take it swimming. Don't give me vague marketing speak—I want technical specifications and warranty coverage for water damage.
# Department: Tech Support
# --------------------------------------------------
# Email 2:
# Subject: Could you kindly clarify the app requirements?
# Body: Hello there, I hope this message finds you well. I was wondering if you might be able to assist me with understanding what exactly the app needs to function properly? I've been trying to set it up, but I'm not entirely sure about the necessary specifications or permissions it requires. Any guidance you could provide would be greatly appreciated. Thank you so much for your time and assistance!
# Department: Tech Support
# --------------------------------------------------
# Email 3:
# Subject: Help choosing
# Body: Which one should I get???
# Department: Tech Support
# --------------------------------------------------
# Email 4:
# Subject: WavePanel Touch won't pair?
# Body: Having trouble with Bluetooth pairing. Firmware 4.0.9. Need help ASAP.
# Department: Tech Support
# --------------------------------------------------
# Email 5:
# Subject: Yo, why's my SoundBar Flex blinking like crazy?
# Body: Hey, so my SoundBar Flex keeps blinking these lights non-stop. It's kinda annoying. What's up with that?
# Department: Tech Support
# --------------------------------------------------
# Email 6:
# Subject: DOES THIS EVEN WORK WITH MY STUFF??
# Body: I BOUGHT THIS THINKING IT WOULD WORK BUT IT DOESN'T. WHAT'S THE POINT IF IT'S NOT COMPATIBLE????
# Department: Tech Support
# --------------------------------------------------
# Email 7:
# Subject: Need help with BassHub Pro
# Body: The touch panel isn't working... what should I do?
# Department: Tech Support
# --------------------------------------------------
# Email 8:
# Subject: EchoWave One connection issues?
# Body: My EchoWave One won't connect to my network. I'm on firmware 4.7.3. What's going on?
# Department: Tech Support
# --------------------------------------------------
# Email 9:
# Subject: Inquiry about battery life of SoundBlaster X3
# Body: Dear Support Team,
#
# I recently purchased a SoundBlaster X3 (Order #SBX3-2023-45678 on October 15, 2023) and would like to know the expected battery life under normal usage conditions. Could you provide detailed specifications or usage guidelines to maximize battery performance?
#
# Thank you for your assistance.
#
# Best regards,
# [Your Name]
# Department: Tech Support
# --------------------------------------------------
# Email 10:
# Subject: WHY ARE THE LIGHTS BLINKING ON MY BASSHUB PRO???
# Body: I JUST UPDATED TO FIRMWARE 2.4.6 AND NOW THE LIGHTS WON'T STOP BLINKING. FIX THIS NOW!
# Department: Tech Support
# --------------------------------------------------
# Email 11:
# Subject: Hey, my StreamLink Hub isn't making any sound?
# Body: Yo, just got this thing and it's not playing any audio. Tried all the usual stuff, still nada. What's up with that?
# Department: Tech Support
# --------------------------------------------------
# Email 12:
# Subject: AuraPods Gen 2 Overheating Issue - Order #45782
# Body: I purchased the AuraPods Gen 2 on March 15th (Order #45782) and have been experiencing constant overheating issues since day one. The firmware is up to date (v2.0.6), so I’m not sure what else you expect me to do. They get uncomfortably hot within 15 minutes of use—almost like they’re trying to melt my ears. I’ve followed all the troubleshooting steps on your website, but surprise, nothing works. Maybe you can actually help this time?
# Department: Tech Support
# --------------------------------------------------
# Email 13:
# Subject: Wow, great product guys
# Body: So my EchoWave just loves restarting. Like, every 5 minutes. Super fun. 10/10 would not recommend.
# Department: Tech Support
# --------------------------------------------------
# Email 14:
# Subject: Is my EchoWave Mini allergic to Wi-Fi or something?
# Body: So my EchoWave Mini keeps dropping connection like it's got commitment issues. What's the deal? Do I need to perform some tech exorcism or is this a known thing?
# Department: Tech Support
# --------------------------------------------------
# Email 15:
# Subject: SoundBar Flex is garbage
# Body: Won't connect. Fix it now.
# Department: Tech Support
# --------------------------------------------------
# Email 16:
# Subject: Why can't the app find my WavePanel Touch?
# Body: Hi, I just got my WavePanel Touch and the app can't seem to find it. I'm on firmware version 2.8.1. Is there something I'm missing? Do I need to update something? It's really confusing.
# Department: Tech Support
# --------------------------------------------------
# Email 17:
# Subject: Need advice on which product to choose
# Body: I'm looking for a good pair of headphones for gaming and music. Can you recommend something? I'm not sure which model would be best for my needs.
# Department: Tech Support
# --------------------------------------------------
# Email 18:
# Subject: EchoWave One Plus Bluetooth issues?
# Body: Hi, I'm having trouble pairing my EchoWave One Plus with any Bluetooth devices. It's running firmware 4.7.0. Is this a known issue?
# Department: Tech Support
# --------------------------------------------------
# Email 19:
# Subject: WHY DOES MY STREAMLINK HUB KEEP DISCONNECTING???
# Body: THIS THING IS DRIVING ME CRAZY! IT WORKS FOR LIKE 5 MINUTES THEN DIES. FIX IT!!!
# Department: Tech Support
# --------------------------------------------------
# Email 20:
# Subject: EchoWave overheating??
# Body: This thing gets way too hot. Fix it.
# Department: Tech Support
# --------------------------------------------------
# Email 21:
# Subject: AuraPods Gen 2 not working after firmware update
# Body: Hi, I updated the firmware on my AuraPods Gen 2 and now they won't connect properly. What's going on? Can you help?
# Department: Tech Support
# --------------------------------------------------
# Email 22:
# Subject: Did your latest firmware update come with a free brick feature?
# Body: So I updated my BassHub Pro Limited like a good little customer and now it's about as useful as a paperweight. What genius thought this was a good idea?
# Department: Tech Support
# --------------------------------------------------
# Email 23:
# Subject: StreamLink Hub keeps disconnecting - fix this crap
# Body: Order #SLH-2023-45678 from 10/15/2023. The StreamLink Hub disconnects randomly every 10 minutes. I paid good money for this POS. What's the deal?
# Department: Tech Support
# --------------------------------------------------
# Email 24:
# Subject: Compatibility question
# Body: Hey, just got your new speaker. Will it work with older iPods? Need to know ASAP.
# Department: Tech Support
# --------------------------------------------------
# Email 25:
# Subject: Is your 'waterproof' speaker actually waterproof?
# Body: Hey geniuses, I bought your UltraSound X200 speaker (order #USX200-78945 on 05/15/2023) because your marketing claimed it was '100% waterproof for pool parties.' Well guess what? Took it near my kiddie pool yesterday and now it sounds like a dying robot. Either your waterproof rating is a joke or my 3-inch-deep pool is the Atlantic Ocean. Care to explain?
# Department: Tech Support
# --------------------------------------------------
# Email 26:
# Subject: EchoWave One not connecting?
# Body: Hey, my EchoWave One won't connect to anything. Firmware is 4.2.4. What's up with that?
# Department: Tech Support
# --------------------------------------------------
# Email 27:
# Subject: Does your headset support multipoint?
# Body: Hi, I recently bought one of your wireless headsets but I'm not sure if it supports multipoint connection. Can I connect to two devices at the same time? Also, how do I set it up if it does? Thanks!
# Department: Tech Support
# --------------------------------------------------
# Email 28:
# Subject: App issue
# Body: What does it need? Can't figure it out. Help!
# Department: Tech Support
# --------------------------------------------------
# Email 29:
# Subject: YOUR PRODUCT IS GARBAGE
# Body: BUTTONS DON'T WORK!!! FIX THIS NOW!!!
# Department: Tech Support
# --------------------------------------------------
# Email 30:
# Subject: SoundBar Flex volume is way too low - fix this!
# Body: Order #SB456789, purchased on 10/15/2023. The SoundBar Flex volume is ridiculously low even at max settings. Firmware version is 2.3.6. This is unacceptable for a $200 product. Fix it or refund me.
# Department: Tech Support
# --------------------------------------------------
# Email 31:
# Subject: Unexpected charge for Echo+ Unlimited subscription after cancellation
# Body: Hi, I noticed a charge of $7.99 on June 08 for my Echo+ Unlimited subscription, even though I canceled it before that date. The payment was processed through PayPal. Can you confirm why this charge occurred and if I can get a refund? Also, can you verify that my subscription is indeed canceled to prevent future charges? Thank you for your help.
# Department: Billing
# --------------------------------------------------
# Email 32:
# Subject: Why was I charged $29.99 for Echo+ Unlimited after canceling?
# Body: Hey there, I canceled my Echo+ Unlimited subscription last month, but I just saw a charge for $29.99 on June 19 on my credit card. Can you check this out and refund me? Thanks!
# Department: Billing
# --------------------------------------------------
# Email 33:
# Subject: Question about my Echo+ Unlimited charge
# Body: Hi, I noticed a charge of $7.99 on June 23 for my Echo+ Unlimited subscription, but it doesn't match my invoice. Could you help clarify this? The payment was made via bank account.
# Department: Billing
# --------------------------------------------------
# Email 34:
# Subject: Question about recent charge for Echo+ Unlimited
# Body: Hi, I noticed a charge of $14.99 on June 17 for my Echo+ Unlimited subscription, but I think I might have been billed twice. Could you please check this for me? Thank you!
# Department: Billing
# --------------------------------------------------
# Email 35:
# Subject: Inquiry Regarding Double Billing for Echo+ Unlimited Subscription on June 09
# Body: Dear Support Team, I hope this message finds you well. I am writing to kindly bring to your attention an issue I have encountered with my Echo+ Unlimited subscription. On June 09, I noticed a charge of $14.99 to my bank account, which appears to be a duplicate as I was already billed for the same amount earlier this month. I would greatly appreciate it if you could investigate this matter and provide clarification or a refund for the duplicate charge. Thank you so much for your time and assistance. Warm regards,
# Department: Billing
# --------------------------------------------------
# Email 36:
# Subject: Why was I charged after canceling Echo+ Unlimited?
# Body: I canceled my Echo+ Unlimited subscription but was still charged $14.99 on June 24. Can you please explain this and refund the charge?
# Department: Billing
# --------------------------------------------------
# Email 37:
# Subject: WTF is this charge???
# Body:
# Department: Billing
# --------------------------------------------------
# Email 38:
# Subject: Why was I charged after canceling?
# Body: I canceled SmartSound Premium but still got charged $29.99 on June 04. Can you fix this?
# Department: Billing
# --------------------------------------------------
# Email 39:
# Subject: Question about recent charge after cancellation
# Body: Hi, I noticed I was charged $14.99 on June 20 for my HomeAudio Pro subscription, even though I had canceled it. Could you please check and refund this charge? It was billed to my bank account. Thanks!
# Department: Billing
# --------------------------------------------------
# Email 40:
# Subject: Double charge on my subscription?
# Body: Hey, I just noticed I was charged twice for HomeAudio Pro on June 12. Both were $14.99. Can you check this?
# Department: Billing
# --------------------------------------------------
# Email 41:
# Subject: Question about unexpected charge on my account
# Body: Hello, I noticed a charge of $7.99 on my credit card on June 13 for HomeAudio Pro. I don't recall authorizing this. Could you please clarify what this charge is for?
# Department: Billing
# --------------------------------------------------
# Email 42:
# Subject: WTF is this charge???
# Body: $29.99 for what??
# Department: Billing
# --------------------------------------------------
# Email 43:
# Subject: Question about double billing on HomeAudio Pro subscription
# Body: Hi, I noticed I was charged $29.99 twice on June 10 for my HomeAudio Pro subscription. It was billed to my bank account. Could you help clarify this? Thanks!
# Department: Billing
# --------------------------------------------------
# Email 44:
# Subject: Double billing issue with SmartSound Premium subscription
# Body: Hello, I noticed that I was charged twice for my SmartSound Premium subscription on June 05. Both charges were for $7.99 and were deducted from my bank account. Could you please look into this and refund the duplicate charge? Thank you for your assistance.
# Department: Billing
# --------------------------------------------------
# Email 45:
# Subject: Discrepancy in Echo+ Unlimited Subscription Charge on June 18
# Body: Dear Support Team, I noticed a discrepancy in my recent charge for the Echo+ Unlimited subscription. On June 18, I was charged $7.99, but this amount does not match my invoice. The billing method used was my bank account. Could you please verify this charge and provide clarification? Thank you for your assistance.
# Department: Billing
# --------------------------------------------------
# Email 46:
# Subject: Unexpected charge for SmartSound Premium after cancellation
# Body: Hi, I canceled my SmartSound Premium subscription on June 15, but I was still charged $29.99 on June 23. Can you confirm why this happened and issue a refund? My order number is #SSP20230615. I paid with my credit card. Please let me know if you need any additional information.
# Department: Billing
# --------------------------------------------------
# Email 47:
# Subject: Why was I charged $7.99?
# Body: What is this charge for SmartSound Premium on June 03? It doesn't match my invoice. Fix it.
# Department: Billing
# --------------------------------------------------
# Email 48:
# Subject: Unexpected $14.99 charge for HomeAudio Pro on June 04 via PayPal
# Body: I was charged $14.99 on June 04 for HomeAudio Pro through PayPal without any prior notification or authorization. I demand an immediate refund and an explanation for this unauthorized transaction. Confirm the refund and provide a resolution within 24 hours.
# Department: Billing
# --------------------------------------------------
# Email 49:
# Subject: Incorrect charge for HomeAudio Pro subscription on June 17
# Body: I noticed a discrepancy in my invoice for the HomeAudio Pro subscription. I was charged $14.99 on June 17, but this doesn't match my records. The payment was processed through my bank account. Could you please verify this charge and clarify the mismatch? My order number is #HA20230617. Thank you.
# Department: Billing
# --------------------------------------------------
# Email 50:
# Subject: WTF is this charge???
# Body: You double billed me for Echo+ Unlimited. Fix this now!
# Department: Billing
# --------------------------------------------------
# Email 51:
# Subject: Request for Clear Return Instructions for PulseDock (Order #12238)
# Body: Dear Support Team, I hope this message finds you well. I am writing to kindly request some clarification regarding the return process for my PulseDock, which I ordered on August 26 (Order #12238). I am located in the USA and unfortunately need to return the item, but I found the return instructions to be somewhat unclear. Additionally, I wanted to mention that I originally purchased this item for an upcoming event, so I would greatly appreciate any expedited assistance you could provide. Thank you so much for your time and help. Warm regards,
# Department: Shipping
# --------------------------------------------------
# Email 52:
# Subject: NEED CLEAR RETURN INSTRUCTIONS FOR AURAPODS GEN 2 (ORDER #14712)
# Body: I ORDERED AURAPODS GEN 2 ON AUGUST 16 (ORDER #14712) TO SWEDEN AND NEED TO RETURN THEM. YOUR RETURN INSTRUCTIONS ARE COMPLETELY UNCLEAR! I NEED A FAST RESOLUTION – THIS IS RIDICULOUS. SEND ME THE DAMN RETURN LABEL AND CLEAR STEPS NOW!
# Department: Shipping
# --------------------------------------------------
# Email 53:
# Subject:
# Body: Great job sending my BassHub to Narnia. Want to try again? Or just refund me?
# Department: Shipping
# --------------------------------------------------
# Email 54:
# Subject: Missing return label
# Body: Hi, I already emailed about this but still haven't received the return label for my BassHub Pro Limited. Could you please help?
# Department: Shipping
# --------------------------------------------------
# Email 55:
# Subject: StreamLink Hub Order #26905 Not Delivered
# Body: Ordered StreamLink Hub on August 04 to France. Still not delivered. Already emailed once. Need update ASAP.
# Department: Shipping
# --------------------------------------------------
# Email 56:
# Subject: Hey, sent to wrong address?
# Body: Yo, I think my PulseDock got sent to the wrong place. I'm in Sweden. Can you fix this ASAP? Thanks!
# Department: Shipping
# --------------------------------------------------
# Email 57:
# Subject: Where is my StreamLink Hub??
# Body: This is unacceptable. Still stuck in transit and I already emailed about this. Sort it out NOW.
# Department: Shipping
# --------------------------------------------------
# Email 58:
# Subject: Where's my return label?
# Body: Oh, fantastic. Ordered a PulseDock in July, now trying to return it but guess what? No return label. Germany isn't that far, you know. How about a fast resolution for once?
# Department: Shipping
# --------------------------------------------------
# Email 59:
# Subject: Seriously?
# Body: Your return instructions make no sense. I have an event coming up and now I'm stuck with these AuraPods. Fix this.
# Department: Shipping
# --------------------------------------------------
# Email 60:
# Subject: Tracking information missing for AuraPods Gen 2 (Order #77032)
# Body: Hello, I ordered the AuraPods Gen 2 on July 03 (Order #77032) to be shipped to France, but I haven't received any tracking information yet. Could you please provide an update on the shipping status? I would appreciate a fast resolution as I need the product soon. Thank you for your help!
# Department: Shipping
# --------------------------------------------------
# Email 61:
# Subject: Order #14191 - BassHub Pro Limited Stuck in Transit
# Body: Hi, I ordered the BassHub Pro Limited on July 07 (order #14191) to be shipped to the USA. The tracking shows it's been stuck in transit for a while now. I really need this resolved quickly as I was counting on receiving it soon. Can you please look into this and provide an update? Thanks.
# Department: Shipping
# --------------------------------------------------
# Email 62:
# Subject: Wrong address on my BassHub Pro order - fix this now!
# Body: I ordered the BassHub Pro Limited but you sent it to the wrong address. I need this resolved immediately. What are you going to do about it?
# Department: Shipping
# --------------------------------------------------
# Email 63:
# Subject: Need clear return instructions for AuraPods ASAP
# Body: I ordered AuraPods in November and need to return them. Your instructions are unclear. I need this resolved quickly - what's the process?
# Department: Shipping
# --------------------------------------------------
# Email 64:
# Subject: Did you send my EchoWave One to Narnia?
# Body: So, my EchoWave One decided to take a vacation somewhere that's definitely not my address. Can we fix this before it starts sending postcards?
# Department: Shipping
# --------------------------------------------------
# Email 65:
# Subject: Missing return label for EchoWave One?
# Body: Hey, I need to return my EchoWave One but there's no label. Already emailed about this. What's going on?
# Department: Shipping
# --------------------------------------------------
# Email 66:
# Subject: Where's my EchoWave Mini?
# Body: Hey, I ordered an EchoWave Mini a while ago and it's still stuck in transit. I already emailed about this once. What's going on?
# Department: Shipping
# --------------------------------------------------
# Email 67:
# Subject: Where's my BassHub Pro?
# Body: Ordered in Feb, no tracking info. Need it for an event soon. What's going on?
# Department: Shipping
# --------------------------------------------------
# Email 68:
# Subject:
# Body: Oh dear, I do hope this message finds you well. I must say, I'm ever so slightly concerned about my lovely SoundBar Flex. It seems to be, well, stuck somewhere? I'd be ever so grateful if you could perhaps look into this matter with the utmost urgency. Many thanks in advance for your kind assistance.
# Department: Shipping
# --------------------------------------------------
# Email 69:
# Subject: Request for Clarification on Return Instructions for AuraPods (Order #17413)
# Body: Dear Support Team,
#
# I hope this message finds you well. I am writing to kindly request some clarification regarding the return process for my AuraPods, which I purchased on August 22 (Order #17413). I am currently located in France and need to return the item, but I found the instructions provided to be somewhat unclear. Additionally, I would like to mention that I need this item for an upcoming event, so any expedited assistance would be greatly appreciated.
#
# Could you please provide me with detailed, step-by-step instructions on how to proceed with the return? I want to ensure that I follow the correct procedure to avoid any delays or issues.
#
# Thank you so much for your time and assistance. I truly appreciate your help and look forward to your prompt response.
#
# Warm regards,
# Department: Shipping
# --------------------------------------------------
# Email 70:
# Subject: Need clearer return instructions for BassHub Pro
# Body: I ordered the BassHub Pro Limited last month and need to return it, but the instructions aren't clear. I already emailed about this once but haven't heard back. Can you help?
# Department: Shipping
# --------------------------------------------------
# Email 71:
# Subject: Missing return label for BassHub Pro?
# Body: Hi, I ordered the BassHub Pro Limited but didn't get a return label. I need this item for an event soon - how do I return it? Also, will it arrive in time if I send it back now?
# Department: Shipping
# --------------------------------------------------
# Email 72:
# Subject: Question about PulseDock delivery
# Body: Hi, I ordered a PulseDock in July and it hasn't arrived yet. I already sent an email about this but haven't heard back. Could you check on the status? I'm in the Netherlands.
# Department: Shipping
# --------------------------------------------------
# Email 73:
# Subject: Need clarification on return process for BassHub Pro Limited
# Body: Hi, I recently purchased the BassHub Pro Limited and need to return it. I'm not entirely clear on the return instructions. I already sent an email about this but haven't heard back. Could you please provide more details? Thank you.
# Department: Shipping
# --------------------------------------------------
# Email 74:
# Subject: WHERE IS MY RETURN LABEL???
# Body: I ORDERED THE PULSEDOCK AND NEED TO RETURN IT BUT THERE'S NO LABEL! HOW AM I SUPPOSED TO GET MY REFUND??
# Department: Shipping
# --------------------------------------------------
# Email 75:
# Subject: Where is my WavePanel Touch?
# Body: Ordered in August, still not here. Already emailed about this. What's going on?
# Department: Shipping
# --------------------------------------------------
# Email 76:
# Subject: Regarding a privacy concern with my recent purchase
# Body: Dear Support Team, I hope this message finds you well. I am writing to express a concern regarding the privacy aspects of my recent purchase from your esteemed company. I would greatly appreciate it if you could kindly provide me with some clarification on how my personal data is being handled. I understand that these matters can be complex, but I would be most grateful for your prompt attention to this issue. Thank you ever so much for your time and assistance. Warm regards,
# Department: Legal
# --------------------------------------------------
# Email 77:
# Subject: Question about data privacy
# Body: Hello, I recently purchased one of your audio products and I'm concerned about how my personal data is being handled. Could you clarify your privacy policy? I'm considering my legal options if this isn't resolved.
# Department: Legal
# --------------------------------------------------
# Email 78:
# Subject:
# Body: Good day, I hope this message finds you well. I am writing to you with a rather delicate matter that has been weighing on my mind. It pertains to a certain policy that I find myself in disagreement with, and I was wondering if you might be able to shed some light on the situation. I do apologize for the inconvenience, but I would be ever so grateful for your assistance in this matter. Thank you kindly for your time and understanding.
# Department: Legal
# --------------------------------------------------
# Email 79:
# Subject: Privacy concern regarding my data
# Body: Hi, I recently noticed some activity with my personal data that I didn't authorize. Could you please look into this and let me know what steps you're taking to address it? Thanks!
# Department: Legal
# --------------------------------------------------
# Email 80:
# Subject: Urgent: GDPR Data Deletion Request for Order #12345
# Body: Hello, I am writing to formally request the deletion of all my personal data under GDPR regulations. My order number is #12345, placed on 2023-05-15 for the SoundBlaster X3 headset. I demand immediate action on this request as it is my legal right. Please confirm once my data has been deleted and provide a detailed report of what was removed. Thank you.
# Department: Legal
# --------------------------------------------------
# Email 81:
# Subject: Urgent: Delete my data under GDPR - Order #UK789456
# Body: Hey there, I need you to delete all my personal data ASAP under GDPR rules. I bought your Wireless Pro Earbuds (Order #UK789456 on 15/03/2024) and want all records wiped. This isn't a request - it's my legal right. Get it done within 24 hours or I'm reporting you to the ICO. Cheers.
# Department: Legal
# --------------------------------------------------
# Email 82:
# Subject: What's your refund policy?
# Body: I want my money back NOW. This is unacceptable.
# Department: Legal
# --------------------------------------------------
# Email 83:
# Subject: URGENT: GDPR Data Deletion Request for Order #DE123456
# Body: I demand immediate action on my GDPR data deletion request for my purchase of the AudioTech Pro X headphones (Order #DE123456, purchased on 2023-11-15). Under EU law, you are required to delete all my personal data without undue delay. Confirm completion within 48 hours.
# Department: Legal
# --------------------------------------------------
# Email 84:
# Subject: Request for account deletion
# Body: I would like to request the immediate removal of my account and all associated data from your system. Could you confirm when this will be completed?
# Department: Legal
# --------------------------------------------------
# Email 85:
# Subject: This is unacceptable!
# Body: Fix this NOW or I'm taking legal action.
# Department: Legal
# --------------------------------------------------
# Email 86:
# Subject: So... what can I actually get?
# Body: 25 StreamLink Hubs. Budget is 'whatever'. Surprise me.
# Department: Sales
# --------------------------------------------------
# Email 87:
# Subject: URGENT: STOCK AVAILABILITY FOR BASSHUB PRO LIMITED - ORDER #RES250
# Body: HEY GLOBALELECTRO, I NEED TO KNOW IF YOU HAVE 250 BASSHUB PRO LIMITED UNITS IN STOCK RIGHT NOW. THIS IS FOR A RESELLER DEAL AND I NEED THEM THIS WEEK. DON'T GIVE ME THE RUNAROUND - JUST TELL ME IF YOU CAN DELIVER OR NOT. ORDER #RES250. RESPOND IMMEDIATELY.
# Department: Sales
# --------------------------------------------------
# Email 88:
# Subject: Inquiry About Reseller Opportunities for BassHub Pro Limited
# Body: Dear MegaTech Retail Team, I hope this message finds you well. I am reaching out to kindly inquire about potential reseller opportunities for the BassHub Pro Limited. I am particularly interested in purchasing a quantity of 10 units and was wondering if you might have any recommendations or special deals available for resellers. Additionally, I would greatly appreciate any guidance on how to proceed within the next month. Thank you so much for your time and assistance. Warm regards,
# Department: Sales
# --------------------------------------------------
# Email 89:
# Subject: Urgent: Shipping Time for 10 PulseDock Units (Order #ESP-2023-4567)
# Body: Hello Elite Sound Partners team, I placed an order for 10 PulseDock units (Order #ESP-2023-4567) on October 10th, 2023, for internal company use. Our deadline is urgent—we need these delivered by the end of this week. Could you confirm the shipping timeline and provide tracking details as soon as possible? Thank you.
# Department: Sales
# --------------------------------------------------
# Email 90:
# Subject: Inquiry about EchoWave Mini for influencer campaign
# Body: Hello, I'm interested in the EchoWave Mini for an influencer campaign and would like to know if it's possible to test a sample unit before placing a larger order. The campaign deadline is in about a month. Could you provide more details on this?
# Department: Sales
# --------------------------------------------------
# Email 91:
# Subject: Urgent: Stock Availability for AuraPods Gen 2 (Order #RES-250-ACD)
# Body: I need immediate confirmation on stock availability for 250 units of AuraPods Gen 2. This is for a reseller deal with a hard deadline of 1 month. Please respond ASAP with confirmation and next steps. Do not waste my time—I need clear answers today.
# Department: Sales
# --------------------------------------------------
# Email 92:
# Subject: Custom branding for StreamLink Hub?
# Body: Need info ASAP. How fast can you do custom branding for 25 units? This week or not?
# Department: Sales
# --------------------------------------------------
# Email 93:
# Subject: Quick question about EchoWave One Plus availability?
# Body: Hi there! I'm super excited about the EchoWave One Plus and wanted to check if you have 50 units in stock? We're looking to use them internally and need them within a month. Thanks so much for your help!
# Department: Sales
# --------------------------------------------------
# Email 94:
# Subject: NEED HELP WITH PULSEDOCK ORDER ASAP!!!
# Body: I NEED TO ORDER 250 PULSEDOCKS FOR INTERNAL USE THIS WEEK. WHAT ARE MY OPTIONS??? THIS IS URGENT!!!
# Department: Sales
# --------------------------------------------------
# Email 95:
# Subject: Need recommendations for PulseDock influencer campaign
# Body: Hi, I'm planning an influencer campaign for the PulseDock and need some general recommendations. I need to order about 100 units and have a tight deadline of 2 weeks. Can you help me figure out the best approach?
# Department: Sales
# --------------------------------------------------
# Email 96:
# Subject: Inquiry Regarding Shipping Time for BassHub Pro Limited
# Body: Dear MegaTech Retail Team, I hope this message finds you well. I am reaching out to kindly inquire about the estimated shipping time for the BassHub Pro Limited headphones. We are considering a corporate gifting order of 50 units and would greatly appreciate any information you could provide regarding delivery timelines, especially as we have a deadline in approximately two weeks. Thank you ever so much for your time and assistance. Warm regards,
# Department: Sales
# --------------------------------------------------
# Email 97:
# Subject: Request for Sample Unit of WavePanel Touch for Bulk Purchase Evaluation
# Body: I am writing to inquire about the possibility of testing a sample unit of your WavePanel Touch before committing to a bulk purchase of 250 units for internal use. Could you confirm if this is possible and provide details on how to proceed? We are evaluating several options and need to ensure the product meets our requirements. Please respond at your earliest convenience.
# Department: Sales
# --------------------------------------------------
# Email 98:
# Subject: Custom branding??
# Body: Need info ASAP. EchoWave Mini.
# Department: Sales
# --------------------------------------------------
# Email 99:
# Subject: Need help ASAP
# Body: I need to know what to buy, and I don't have time for this. Just tell me what works.
# Department: Sales
# --------------------------------------------------
# Email 100:
# Subject: NEED INFO ON AURAPODS GEN 2 FOR INFLUENCER CAMPAIGN ASAP!!!
# Body: HEY I NEED TO KNOW WHAT YOU RECOMMEND FOR AURAPODS GEN 2 FOR AN INFLUENCER CAMPAIGN. I NEED 10 UNITS BUT NO IDEA WHAT TO DO NEXT. WHY IS THIS SO COMPLICATED??
# Department: Sales
# --------------------------------------------------

# %%
import pandas as pd

df = pd.DataFrame(all_emails)

df
# Out:
#                                               subject  \
# 0   Is the SoundBuds Pro truly waterproof? Need cl...
# 1      Could you kindly clarify the app requirements?
# 2                                       Help choosing
# 3                         WavePanel Touch won't pair?
# 4     Yo, why's my SoundBar Flex blinking like crazy?
# ..                                                ...
# 95  Inquiry Regarding Shipping Time for BassHub Pr...
# 96  Request for Sample Unit of WavePanel Touch for...
# 97                                  Custom branding??
# 98                                     Need help ASAP
# 99  NEED INFO ON AURAPODS GEN 2 FOR INFLUENCER CAM...
#
#                                                  body    department
# 0   I recently purchased the SoundBuds Pro (Order ...  Tech Support
# 1   Hello there, I hope this message finds you wel...  Tech Support
# 2                           Which one should I get???  Tech Support
# 3   Having trouble with Bluetooth pairing. Firmwar...  Tech Support
# 4   Hey, so my SoundBar Flex keeps blinking these ...  Tech Support
# ..                                                ...           ...
# 95  Dear MegaTech Retail Team, I hope this message...         Sales
# 96  I am writing to inquire about the possibility ...         Sales
# 97                     Need info ASAP. EchoWave Mini.         Sales
# 98  I need to know what to buy, and I don't have t...         Sales
# 99  HEY I NEED TO KNOW WHAT YOU RECOMMEND FOR AURA...         Sales
#
# [100 rows x 3 columns]

# %%
from paths import DATA_DIR

df.to_csv(DATA_DIR / "customer_support_emails_dataset.csv", index=True)
